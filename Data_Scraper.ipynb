# %%
# !pip install pytube
# !pip install spotipy
# !pip install ytmusicapi
# Out:
# Requirement already satisfied: pytube in /opt/conda/lib/python3.10/site-packages (15.0.0)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (0.25.1)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 64 not upgraded.

# %%
from ytmusicapi import YTMusic
import ytmusicapi
from pprint import pprint
import os
from pytube import YouTube
import urllib.request
import requests
import string
from spotipy import SpotifyOAuth
from spotipy.oauth2 import SpotifyOauthError, SpotifyClientCredentials
import pandas as pd
import numpy as np
import json
import concurrent.futures
import time
import threading
from pydub import AudioSegment
from IPython.display import Audio

# %%
audio = AudioSegment.from_file('/kaggle/working/songs/9rj1NPEWOH4.mp4')
wav_path = 'test' + ".wav"
audio.export(wav_path, format="wav")
# Out:
# <_io.BufferedRandom name='test.wav'>

# %% [markdown]
# # Scrapper Class Definition

# %%
class YTScraper:
  def __init__(
    self,
    token_file_path = 'oauth.json',
  ):
    self.yt_music = YTMusic(token_file_path)
    
  def get_search_results(self,search_str):
    return self.yt_music.search(search_str,filter = 'songs')
  
  def get_lyrics(self, video_id):
    video=self.yt_music.get_watch_playlist(videoId=video_id)
    lyrics_id = video['lyrics']
    lyrics = None
    if lyrics_id:
      lyrics=self.yt_music.get_lyrics(lyrics_id)
    return lyrics
  
  def download_song_by_video_id(
    self,
    video_id,
    output_path=None,
  ):
    if output_path is not None:
      os.makedirs(output_path,exist_ok=True)
    else:
      output_path = ""
    yt = YouTube(f"https://youtube.com/watch?v={video_id}", use_oauth = True, allow_oauth_cache=True)
    temp_file = os.path.join(output_path,f"{video_id}.mp4")
    yt.streams.filter(only_audio=True).first().download(output_path=output_path, filename=f"{video_id}.mp4")
    if os.path.exists(temp_file):
      print(f"Downloaded successfully: {temp_file}")
    return os.path.join(output_path,f"{video_id}.mp4")
  
  def scrap_by_search(self, search_str, download_output_file_path = None):
    search_result = self.get_search_results(search_str=search_str)
    video_id = None
    for item in search_result:
      if item['resultType'] in ['song'] and item['category'] == 'Songs':
        video_id = item['videoId']
        break 
    if (video_id):
      lyrics = self.get_lyrics(video_id=video_id)
      if not lyrics:
        lyrics = {'lyrics':None,'source':None}
      download_path = self.download_song_by_video_id(video_id=video_id, output_path=download_output_file_path)
    else:
      raise Exception("Null Video Id")
    return {
      "lyrics" : lyrics['lyrics'],
      "audio_file_path" : download_path
    }
  
class SpotifyScraper:
    def __init__(
        self,
        client_id,
        client_secret,
        redirect_uri,
        scope = "user-library-read playlist-read-private playlist-read-collaborative"
        
    ):
        self.yt_scraper = YTScraper()
        self._credentials = SpotifyClientCredentials(client_id = client_id, client_secret = client_secret)
        self.access_token = self.get_access_token()
            
    def get_access_token(self):
        # Get access token
        access_token = self._credentials.get_access_token(as_dict = False)
        if not access_token:
            raise Exception("Access Token Not Found")
        return access_token

    def get_auth_header(self):
        return {"Authorization": "Bearer " + self.access_token}
    # Function to fetch user playlists
    
    def get_user_playlists(self):
        print("Retrieving user playlists...")
        headers = self.get_auth_header()
        response = requests.get("https://api.spotify.com/v1/me/playlists", headers=headers)
        response_json = response.json()
        # for item in response_json["items"]:
        #     playlists[item["name"]] = item["id"]
        print("Playlists retrieved successfully.")
        return response_json
    
    @staticmethod
    def sanitize_filename(filename):
        valid_chars = "-_.() %s%s" % (string.ascii_letters, string.digits)
        return ''.join(c for c in filename if c in valid_chars)

    def get_track_info_by_id(self, track_id):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/tracks/{track_id}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_playlist_info_by_id(self, playlist_id):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_track_info_by_id(self, track_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/tracks?ids={track_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_artist_info_by_id(self, artist_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/artists?ids={artist_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_audio_feature_by_id(self, track_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/audio-features?ids={track_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def destructure_artist_data(self,artists_list):
        artist_infos = []
        artist_genres = []
        artist_popularities = []
        artist_followers = []
        for artist_obj in artists_list:
            artist_infos.append({
                "name": artist_obj["name"],
                "id": artist_obj["id"],
                "genres": artist_obj.get("genres", []),
                "popularity": artist_obj["popularity"],
                "followers": artist_obj["followers"]["total"]
            })
            artist_genres.extend(artist_obj.get("genres", []))
            artist_popularities.append(artist_obj["popularity"])
            artist_followers.append(artist_obj["followers"]["total"])
        return {
            'artist_infos' : artist_infos,
            'artist_genres' : artist_genres,
            'artist_popularities' : artist_popularities,
            'artist_followers' : artist_followers,
        }
        
    
    def construct_track_info_dict(self,track_json = None, audio_features_json = None, artist_json = None): 
        
        most_popular_artist = max(artist_json['artist_infos'], key=lambda x: x["popularity"])
        
        search_str = f"{track_json['name']} {most_popular_artist['name']}"
        
        lyrics_audio_data = self.yt_scraper.scrap_by_search(search_str=search_str, download_output_file_path = "songs")
        
        track_info = {
        "track_name": track_json["name"],
        "track_id": track_json["id"],
        "track_number": track_json["track_number"],
        "disc_number": track_json["disc_number"],
        "duration_ms": track_json["duration_ms"],
        "explicit": track_json["explicit"],
        "popularity": track_json["popularity"],
        "preview_url": track_json["preview_url"],
        "isrc": track_json["external_ids"].get("isrc"),
        "album_name": track_json["album"]["name"],
        "album_id": track_json["album"]["id"],
        "album_type": track_json["album"]["album_type"],
        "album_total_tracks": track_json["album"]["total_tracks"],
        "album_release_date": track_json["album"]["release_date"],
        "album_release_date_precision": track_json["album"]["release_date_precision"],
        "album_images": track_json["album"]["images"],
        "popular_artist": most_popular_artist["name"],
        "popular_artist_id": most_popular_artist["id"],
        "artist_names": [artist["name"] for artist in track_json["artists"]],
        "artist_ids": [artist["id"] for artist in track_json["artists"]],
        "combined_genres": list(set(artist_json['artist_genres'])),
        "artist_popularity": most_popular_artist["popularity"],
        "artist_followers": most_popular_artist["followers"],
        "external_url": track_json["external_urls"]["spotify"],
        "acousticness": audio_features_json["acousticness"],
        "danceability": audio_features_json["danceability"],
        "energy": audio_features_json["energy"],
        "instrumentalness": audio_features_json["instrumentalness"],
        "key": audio_features_json["key"],
        "liveness": audio_features_json["liveness"],
        "loudness": audio_features_json["loudness"],
        "mode": audio_features_json["mode"],
        "speechiness": audio_features_json["speechiness"],
        "tempo": audio_features_json["tempo"],
        "time_signature": audio_features_json["time_signature"],
        "valence": audio_features_json["valence"],
    }
        track_info.update(lyrics_audio_data)
        return track_info
        
    def _get_single_threaded_data(self,track_obj, audio_feat_obj):
        artist_ids_list = [artist['id'] for artist in track_obj["artists"]]
        artists_id_str = ','.join(artist_ids_list[:50])
        artists_data = self.get_several_artist_info_by_id(artists_id_str)["artists"]
        destructured_artist_data = self.destructure_artist_data(artists_list=artists_data)  
        return self.construct_track_info_dict(track_obj, audio_feat_obj, destructured_artist_data)
    
    def _get_multi_threaded_data(self,tracks_json,audio_features_json, max_workers):
        data = []
        with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
            # List of tasks to be executed by the thread pool
            tasks = [
                executor.submit(self._get_single_threaded_data , *args) for args in zip(tracks_json, audio_features_json)
            ]
            
            for future in concurrent.futures.as_completed(tasks):
                try:
                    data.append(future.result())
                except Exception as exc:
                    print(f'Task generated an exception: {exc}') 
        return data
    
    def get_several_track_data(self, track_ids_list : list[str], threaded = False, max_workers = 50):
        data = []
        for idx in range(0,len(track_ids_list),50):
            track_id_str = ",".join(track_ids_list[idx:idx+50])
            tracks_json = self.get_several_track_info_by_id(track_id_str)["tracks"]
            audio_features_json = self.get_several_audio_feature_by_id(track_ids_str=track_id_str)["audio_features"]
            if threaded:
                data.extend(self._get_multi_threaded_data(tracks_json,audio_features_json,max_workers))
            else:
                for track_obj, audio_feat_obj in zip(tracks_json, audio_features_json):
                    data.append(self._get_single_threaded_data(track_obj, audio_feat_obj))
        return data

# %% [markdown]
# ## Loading the Environment and Authentication

# %%
import os
import json

from kaggle_secrets import UserSecretsClient
secrets = UserSecretsClient()

os.environ['KAGGLE_USERNAME'] = secrets.get_secret("KAGGLE_USERNAME")
os.environ['KAGGLE_KEY'] = secrets.get_secret("KAGGLE_KEY")
client_id = secrets.get_secret("SPOTIFY_CLIENT_ID")
client_secret = secrets.get_secret("SPOTIFY_CLIENT_SECRET")
redirect_uri = secrets.get_secret("REDIRECT_URI")
yt_music_oauth_metadata = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Content-Type": "application/json",
    "X-Goog-AuthUser": "0",
    "x-origin": "https://music.youtube.com",
    "Cookie" : secrets.get_secret("YT_MUSIC_COOKIE")
}

with open(os.path.join('/kaggle/working/','oauth.json'), 'w') as f:
    json.dump(yt_music_oauth_metadata, f)

# %% [markdown]
# ## Scrapper Instance

# %%
scrapper = SpotifyScraper(
  client_id=client_id,
  client_secret=client_secret,
  redirect_uri=redirect_uri,
)

# %%
track_ids_list = ['7MJQ9Nfxzh8LPZ9e9u68Fq',
 '1GEBsLDvJGw7kviySRI6GX',
 '0gplL1WMoJ6iYaPgMCL0gX',
 '698ItKASDavgwZ3WjaWjtz',
 '3LlmKSHR3Rs0Y3KHQLAYDk',
 '20R4HfKloPKgXDqU7UKk3x',
 '4RVwu0g32PAqgUiJoXsdF8',
 '6habFhsOp2NvshLv26DqMb',
 '18A7ha5BitZjmdHTCwXFbU',
 '75MNhvTCCKsST3YqqUiU9r',
 '1rfofaqEpACxVEHIZBJe6W',
 '5eGEc27nnhtmcOh6RC890a',
 '5PjdY0CKGZdEuoNab3yDmX',
 '6ocbgoVGwYJhOv1GgI9NsF',
 '1mavQ4WCzXSeL2Dm5DS4GQ',
 '3ebXMykcMXOcLeJ9xZ17XH',
 '36jnG0GLshZiH7oWkOq7gV',
 '3z8h0TU7ReDPLIbEnYhWZb',
 '5SDzo5YMWly9n6hVHvxPwp',
 '0ct6r3EGTcMLPtrXHDvVjc',
 '7BMO7O7ImjV8HNTH74Tshv',
 '561jH07mF1jHuk7KlaeF0s',
 '6or1bKJiZ06IlK0vFvY75k',
 '6M47gaKejso9772SKTa3yH',
 '630sXRhIcfwr2e4RdNtjKN',
 '5QDLhrAOJJdNAmCTJ8xMyW',
 '0lYBSQXN6rCTvUZvg9S0lU',
 '5wANPM4fQCJwkGd4rN57mH',
 '4ZtFanR9U6ndgddUvNcjcG',
 '6RUKPb4LETWmmr3iAEQktW',
 '1P17dC1amhFzptugyAO7Il',
 '2DB4DdfCFMw1iaR6JaR03a',
 '3o9kpgkIcffx0iSwxhuNI2',
 '0QLb1y64s617SAnnDoUZLN',
 '5amAJIEdIVtWYEi4wGp7Fn',
 '5flerg6aEao2VayZezVlgu',
 '39LLxExYz6ewLAcYrzQQyP']

# %%
track_data = scrapper.get_several_track_data(track_ids_list,threaded = True)
# Out:
# Downloaded successfully: songs/Xv9InPzAYbA.mp4
# Downloaded successfully: songs/H9NJenpBV2I.mp4
# Downloaded successfully: songs/NSTUVHsb9xw.mp4
# Downloaded successfully: songs/zlJ0Aj9y67c.mp4
# Downloaded successfully: songs/oDn4eKyhSH4.mp4
# Downloaded successfully: songs/9kznlAwE-8o.mp4
# Downloaded successfully: songs/wKoHR305w_c.mp4
# Downloaded successfully: songs/pIWaVJPl0-c.mp4
# Downloaded successfully: songs/aZwklvDdaVw.mp4
# Downloaded successfully: songs/mJLDjIWuPXU.mp4
# Downloaded successfully: songs/9rj1NPEWOH4.mp4
# Downloaded successfully: songs/Zxnnuj4Vp_g.mp4Downloaded successfully: songs/D1I1x2pYMK0.mp4
#
# Downloaded successfully: songs/HaEYUJ2aRHs.mp4
# Downloaded successfully: songs/hJWSZDJb-W4.mp4
# Downloaded successfully: songs/W4C-NEWrnSQ.mp4
# Downloaded successfully: songs/gFOJkIk8fcs.mp4
# Downloaded successfully: songs/z54b7qAB7p0.mp4
# Downloaded successfully: songs/XfEMj-z3TtA.mp4
# Downloaded successfully: songs/Mi5rkJUoqn0.mp4
# Downloaded successfully: songs/FXovf5dsRTw.mp4
# Downloaded successfully: songs/MBJFPq2Llps.mp4
# Downloaded successfully: songs/rJ0D1GbDq1Q.mp4
# Downloaded successfully: songs/E-nY_n5fPSg.mp4
# Downloaded successfully: songs/RbimXGH5zkE.mp4
# Downloaded successfully: songs/117xdufmtMY.mp4
# Downloaded successfully: songs/XZ868t23Pb4.mp4
# Downloaded successfully: songs/utwMHfDZ6SA.mp4
# Downloaded successfully: songs/owTWCbq_nSk.mp4
# Downloaded successfully: songs/64jjsEtvkdM.mp4
# Downloaded successfully: songs/OsfAnsMY21M.mp4
# Downloaded successfully: songs/G1ej5up7JG0.mp4
# Downloaded successfully: songs/tNJhkrpLGT8.mp4
# Downloaded successfully: songs/aeDdS9aIpck.mp4
# Downloaded successfully: songs/Tq3QbTDRTMs.mp4
# Downloaded successfully: songs/bDlEN5tDMtg.mp4
# Downloaded successfully: songs/vFFT1iAUNDE.mp4

# %%
pprint(track_data)
# Out:
# [{'acousticness': 0.27,
#   'album_id': '1WTTu8JvpNLQShwwO8o4L9',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273cec7c8ebb684882dbaf476f5',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02cec7c8ebb684882dbaf476f5',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851cec7c8ebb684882dbaf476f5',
#                     'width': 64}],
#   'album_name': 'Cradles',
#   'album_release_date': '2019-01-04',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 1,
#   'album_type': 'single',
#   'artist_followers': 1692003,
#   'artist_ids': ['7gXb99Sf9nNmpNYeAgIQFG'],
#   'artist_names': ['Sub Urban'],
#   'artist_popularity': 64,
#   'audio_file_path': 'songs/Xv9InPzAYbA.mp4',
#   'combined_genres': ['modern indie pop'],
#   'danceability': 0.581,
#   'disc_number': 1,
#   'duration_ms': 209829,
#   'energy': 0.585,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/18A7ha5BitZjmdHTCwXFbU',
#   'instrumentalness': 6.48e-05,
#   'isrc': 'GB2LD1800949',
#   'key': 1,
#   'liveness': 0.179,
#   'loudness': -1.87,
#   'lyrics': 'I live inside my own world of make-believe\n'
#             'Kids screaming in their cradles, profanities\n'
#             'I see the world through eyes covered in ink and bleach\n'
#             'Cross out the ones who held my cries and watched me weep\n'
#             '\n'
#             'I love everything\n'
#             "Fire's spreading all around my room\n"
#             "My world's so bright\n"
#             "It's hard to breathe, but that's alright\n"
#             'Hush!\n'
#             '\n'
#             'Shh\n'
#             '\n'
#             'Tape my eyes open to force reality (oh, no, no)\n'
#             "Why can't you just let me eat my weight in glee?\n"
#             'I live inside my own world of make-believe\n'
#             'Kids screaming in their cradles, profanities\n'
#             'Somedays, I feel skinnier than all the other days\n'
#             "Sometimes, I can't tell if my body belongs to me\n"
#             '\n'
#             'I love everything\n'
#             "Fire's spreading all around my room\n"
#             "My world's so bright\n"
#             "It's hard to breathe, but that's alright\n"
#             'Hush\n'
#             '\n'
#             'Shh\n'
#             '\n'
#             'I wanna taste your content\n'
#             'Hold your breath and feel the tension\n'
#             'Devils hide behind redemption\n'
#             'Honesty is a one-way gate to hell\n'
#             'I wanna taste consumption\n'
#             'Breathe faster to waste oxygen\n'
#             'Hear the children sing aloud\n'
#             "It's music 'til the wick burns out\n"
#             'Hush\n'
#             '\n'
#             'Just wanna be carefree lately, yeah\n'
#             'Just kicking up daisies\n'
#             'Got one too many quarters in my pocket\n'
#             "Count 'em like the four-leaf clovers in my locket\n"
#             'Untied laces, yeah\n'
#             'Just tripping on daydreams\n'
#             'Got dirty little lullabies playing on repeat\n'
#             'Might as well just rot around the nursery and count sheep',
#   'mode': 1,
#   'popular_artist': 'Sub Urban',
#   'popular_artist_id': '7gXb99Sf9nNmpNYeAgIQFG',
#   'popularity': 0,
#   'preview_url': None,
#   'speechiness': 0.369,
#   'tempo': 67.443,
#   'time_signature': 3,
#   'track_id': '18A7ha5BitZjmdHTCwXFbU',
#   'track_name': 'Cradles',
#   'track_number': 1,
#   'valence': 0.63},
#  {'acousticness': 0.578,
#   'album_id': '224jZ4sUX7OhAuMwaxp86S',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b27350dba34377a595e35f81b0e4',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e0250dba34377a595e35f81b0e4',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d0000485150dba34377a595e35f81b0e4',
#                     'width': 64}],
#   'album_name': 'Easy On Me',
#   'album_release_date': '2021-10-14',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 1,
#   'album_type': 'single',
#   'artist_followers': 56081028,
#   'artist_ids': ['4dpARuHxo51G3z768sgnrY'],
#   'artist_names': ['Adele'],
#   'artist_popularity': 83,
#   'audio_file_path': 'songs/H9NJenpBV2I.mp4',
#   'combined_genres': ['pop', 'british soul', 'uk pop', 'pop soul'],
#   'danceability': 0.604,
#   'disc_number': 1,
#   'duration_ms': 224694,
#   'energy': 0.366,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/0gplL1WMoJ6iYaPgMCL0gX',
#   'instrumentalness': 0,
#   'isrc': 'USSM12105970',
#   'key': 5,
#   'liveness': 0.133,
#   'loudness': -7.519,
#   'lyrics': "There ain't no gold in this river\n"
#             "That I've been washing my hands in forever\n"
#             '\n'
#             'I know there is hope in these waters\n'
#             '\n'
#             "But I can't bring myself to swim\n"
#             'When I am drowning in this silence\n'
#             '\n'
#             'Baby, let me in\n'
#             '\n'
#             'Go easy on me, baby\n'
#             'I was still a child\n'
#             "Didn't get the chance to\n"
#             'Feel the world around me\n'
#             'I had no time to choose what I chose to do\n'
#             'So, go easy on me\n'
#             '\n'
#             "There ain't no room for our things to change\n"
#             'When we are both so deeply stuck in our ways\n'
#             "You can't deny how hard I've tried\n"
#             'I changed who I was to put you both first\n'
#             '\n'
#             'But now I give up\n'
#             '\n'
#             'Go easy on me, baby\n'
#             'I was still a child\n'
#             "Didn't get the chance to\n"
#             'Feel the world around me\n'
#             'Had no time to choose what I chose to do\n'
#             '\n'
#             'So go easy on me\n'
#             '\n'
#             'I had good intentions\n'
#             '\n'
#             'And the highest hopes\n'
#             '\n'
#             'But I know right nowㅤ\n'
#             "It probably doesn't even show\n"
#             '\n'
#             'Go easy on me, baby\n'
#             'I was still a child\n'
#             "I didn't get the chance to\n"
#             'Feel the world around me\n'
#             'I had no time to choose what I chose to do\n'
#             'So go easy on me',
#   'mode': 1,
#   'popular_artist': 'Adele',
#   'popular_artist_id': '4dpARuHxo51G3z768sgnrY',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a0cd8077c79a4aa3dcaa68bbc5ecdeda46e8d13f?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.0282,
#   'tempo': 141.981,
#   'time_signature': 4,
#   'track_id': '0gplL1WMoJ6iYaPgMCL0gX',
#   'track_name': 'Easy On Me',
#   'track_number': 1,
#   'valence': 0.13},
#  {'acousticness': 0.767,
#   'album_id': '0JGOiO34nwfUdDrD612dOp',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#                     'width': 64}],
#   'album_name': 'Happier Than Ever',
#   'album_release_date': '2021-07-30',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 16,
#   'album_type': 'album',
#   'artist_followers': 95624232,
#   'artist_ids': ['6qqNVTkY8uBg9cP3Jd7DAH'],
#   'artist_names': ['Billie Eilish'],
#   'artist_popularity': 94,
#   'audio_file_path': 'songs/NSTUVHsb9xw.mp4',
#   'combined_genres': ['pop', 'art pop'],
#   'danceability': 0.332,
#   'disc_number': 1,
#   'duration_ms': 298899,
#   'energy': 0.225,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8',
#   'instrumentalness': 0.00349,
#   'isrc': 'USUM72105936',
#   'key': 0,
#   'liveness': 0.128,
#   'loudness': -8.697,
#   'lyrics': "When I'm away from you, I'm happier than ever\n"
#             'Wish I could explain it better\n'
#             "I wish it wasn't true\n"
#             'Give me a day or two to think of something clever\n'
#             'To write myself a letter\n'
#             'To tell me what to do, mm-mmm\n'
#             '\n'
#             'Do you read my interviews?\n'
#             'Or do you skip my avenue? (My avenue)\n'
#             'When you (when you) said you were passing through\n'
#             'Was I even on your way?\n'
#             '\n'
#             'I knew when I asked you to (when I asked you to)\n'
#             'Be cool about what I was telling you\n'
#             "You'd do the opposite of what you said you'd do (what you said "
#             "you'd do)\n"
#             "And I'd end up more afraid\n"
#             '\n'
#             "Don't say it isn't fair\n"
#             "You clearly weren't aware that you made me miserable\n"
#             '\n'
#             'So if you really wanna know\n'
#             '\n'
#             "When I'm away from you (when I'm away from you)\n"
#             "I'm happier than ever (happier than ever)\n"
#             'Wish I could explain it better (wish I could explain it better)\n'
#             "I wish it wasn't true (wish it wasn't true), mmm-mmm\n"
#             '\n'
#             'You call me again, drunk in your Benz\n'
#             'Driving home under the influence\n'
#             "You scared me to death, but I'm wasting my breath\n"
#             "'Cause you only listen to your fucking friends\n"
#             '\n'
#             "I don't relate to you\n"
#             "I don't relate to you, no\n"
#             "'Cause I'd never treat me this shitty\n"
#             'You made me hate this city\n'
#             '\n'
#             "And I don't talk shit about you on the internet\n"
#             'Never told anyone anything bad\n'
#             "'Cause that shit's embarrassing, you were my everything\n"
#             'And all that you did was make me fucking sad\n'
#             "So don't waste the time I don't have\n"
#             "And don't try to make me feel bad\n"
#             '\n'
#             'I could talk about every time that you showed up on time\n'
#             "But I'd have an empty line 'cause you never did\n"
#             'Never paid any mind to my mother or friends\n'
#             "So I shut 'em all out for you 'cause I was a kid\n"
#             '\n'
#             'You ruined everything good\n'
#             'Always said you were misunderstood\n'
#             'Made all my moments your own\n'
#             'Just fucking leave me alone',
#   'mode': 1,
#   'popular_artist': 'Billie Eilish',
#   'popular_artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'popularity': 81,
#   'preview_url': None,
#   'speechiness': 0.0348,
#   'tempo': 81.055,
#   'time_signature': 3,
#   'track_id': '4RVwu0g32PAqgUiJoXsdF8',
#   'track_name': 'Happier Than Ever',
#   'track_number': 15,
#   'valence': 0.297},
#  {'acousticness': 0.00922,
#   'album_id': '3CjuTytLZz3G9znXt2rJgU',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2733f66b5b49ccea004a5ef0db2',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e023f66b5b49ccea004a5ef0db2',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048513f66b5b49ccea004a5ef0db2',
#                     'width': 64}],
#   'album_name': 'SHADYXV',
#   'album_release_date': '2014-11-24',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 28,
#   'album_type': 'compilation',
#   'artist_followers': 85927180,
#   'artist_ids': ['7dGJo4pcD2V6oG8kP0tJRR'],
#   'artist_names': ['Eminem'],
#   'artist_popularity': 91,
#   'audio_file_path': 'songs/zlJ0Aj9y67c.mp4',
#   'combined_genres': ['detroit hip hop', 'hip hop', 'rap'],
#   'danceability': 0.689,
#   'disc_number': 2,
#   'duration_ms': 320626,
#   'energy': 0.735,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/7MJQ9Nfxzh8LPZ9e9u68Fq',
#   'instrumentalness': 0.00072,
#   'isrc': 'USIR10211559',
#   'key': 2,
#   'liveness': 0.365,
#   'loudness': -4.545,
#   'lyrics': None,
#   'mode': 1,
#   'popular_artist': 'Eminem',
#   'popular_artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'popularity': 68,
#   'preview_url': None,
#   'speechiness': 0.267,
#   'tempo': 171.403,
#   'time_signature': 4,
#   'track_id': '7MJQ9Nfxzh8LPZ9e9u68Fq',
#   'track_name': 'Lose Yourself',
#   'track_number': 3,
#   'valence': 0.059},
#  {'acousticness': 0.227,
#   'album_id': '0JGOiO34nwfUdDrD612dOp',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#                     'width': 64}],
#   'album_name': 'Happier Than Ever',
#   'album_release_date': '2021-07-30',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 16,
#   'album_type': 'album',
#   'artist_followers': 95624232,
#   'artist_ids': ['6qqNVTkY8uBg9cP3Jd7DAH'],
#   'artist_names': ['Billie Eilish'],
#   'artist_popularity': 94,
#   'audio_file_path': 'songs/oDn4eKyhSH4.mp4',
#   'combined_genres': ['pop', 'art pop'],
#   'danceability': 0.879,
#   'disc_number': 1,
#   'duration_ms': 173539,
#   'energy': 0.365,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/20R4HfKloPKgXDqU7UKk3x',
#   'instrumentalness': 0.135,
#   'isrc': 'USUM72021500',
#   'key': 2,
#   'liveness': 0.0583,
#   'loudness': -7.781,
#   'lyrics': "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore, I am\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore I am\n'
#             '\n'
#             'Stop, what the hell are you talking about? Ha\n'
#             'Get my pretty name outta your mouth\n'
#             'We are not the same with or without\n'
#             "Don't talk 'bout me like how you might know how I feel\n"
#             "Top of the world, but your world isn't real\n"
#             "Your world's an ideal\n"
#             '\n'
#             'So, go have fun\n'
#             "I really couldn't care less\n"
#             "And you can give 'em my best, but just know\n"
#             '\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore I am\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore I am\n'
#             '\n'
#             "I don't want press to put your name next to mine\n"
#             "We're on different lines, so I\n"
#             'Wanna be nice enough\n'
#             "They don't call my bluff 'cause I hate to find\n"
#             'Articles, articles, articles\n'
#             'Rather you remain unremarkable (got a lotta)\n'
#             'Interviews, interviews, interviews\n'
#             'When they say your name, I just act confused\n'
#             '\n'
#             'Did you have fun?\n'
#             "I really couldn't care less\n"
#             "And you can give 'em my best, but just know\n"
#             '\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore, I am\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore, I am\n'
#             '\n'
#             "I'm sorry\n"
#             "I don't think I caught your name\n"
#             "I'm sorry\n"
#             "I don't think I caught your name\n"
#             '\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore, I am\n'
#             "I'm not your friend or anything, damn\n"
#             "You think that you're the man\n"
#             'I think, therefore I am',
#   'mode': 1,
#   'popular_artist': 'Billie Eilish',
#   'popular_artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'popularity': 70,
#   'preview_url': None,
#   'speechiness': 0.0924,
#   'tempo': 94.016,
#   'time_signature': 4,
#   'track_id': '20R4HfKloPKgXDqU7UKk3x',
#   'track_name': 'Therefore I Am',
#   'track_number': 14,
#   'valence': 0.663},
#  {'acousticness': 0.209,
#   'album_id': '1kTlYbs28MXw7hwO0NLYif',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273726d48d93d02e1271774f023',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02726d48d93d02e1271774f023',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851726d48d93d02e1271774f023',
#                     'width': 64}],
#   'album_name': 'Encore (Deluxe Version)',
#   'album_release_date': '2004-11-12',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 23,
#   'album_type': 'album',
#   'artist_followers': 85927180,
#   'artist_ids': ['7dGJo4pcD2V6oG8kP0tJRR'],
#   'artist_names': ['Eminem'],
#   'artist_popularity': 91,
#   'audio_file_path': 'songs/9kznlAwE-8o.mp4',
#   'combined_genres': ['detroit hip hop', 'hip hop', 'rap'],
#   'danceability': 0.637,
#   'disc_number': 1,
#   'duration_ms': 250760,
#   'energy': 0.678,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/561jH07mF1jHuk7KlaeF0s',
#   'instrumentalness': 0,
#   'isrc': 'USIR10400813',
#   'key': 0,
#   'liveness': 0.156,
#   'loudness': -3.798,
#   'lyrics': None,
#   'mode': 1,
#   'popular_artist': 'Eminem',
#   'popular_artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'popularity': 84,
#   'preview_url': None,
#   'speechiness': 0.266,
#   'tempo': 84.039,
#   'time_signature': 4,
#   'track_id': '561jH07mF1jHuk7KlaeF0s',
#   'track_name': 'Mockingbird',
#   'track_number': 16,
#   'valence': 0.254},
#  {'acousticness': 0.178,
#   'album_id': '3EzFY9Rg0PpbADMth746zi',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b27360cb9332e8c8c7d8e50854b3',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e0260cb9332e8c8c7d8e50854b3',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d0000485160cb9332e8c8c7d8e50854b3',
#                     'width': 64}],
#   'album_name': 'Fearless (Big Machine Radio Release Special)',
#   'album_release_date': '2008-11-11',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 26,
#   'album_type': 'album',
#   'artist_followers': 114267199,
#   'artist_ids': ['06HL4z0CvFAxyc27GXpf02'],
#   'artist_names': ['Taylor Swift'],
#   'artist_popularity': 100,
#   'audio_file_path': 'songs/wKoHR305w_c.mp4',
#   'combined_genres': ['pop'],
#   'danceability': 0.687,
#   'disc_number': 1,
#   'duration_ms': 232120,
#   'energy': 0.745,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/1GEBsLDvJGw7kviySRI6GX',
#   'instrumentalness': 1.59e-05,
#   'isrc': 'USCJY0803328',
#   'key': 6,
#   'liveness': 0.111,
#   'loudness': -4.432,
#   'lyrics': "You're on the phone with your girlfriend, she's upset\r\n"
#             "She's goin' off about somethin' that you said\r\n"
#             "'Cause she doesn't get your humor like I do\r\n"
#             "I'm in the room, it's a typical Tuesday night\r\n"
#             "I'm listenin' to the kind of music she doesn't like\r\n"
#             "And she'll never know your story like I do\r\n"
#             '\r\n'
#             'But she wears short skirts, I wear T-shirts\r\n'
#             "She's cheer captain and I'm on the bleachers\r\n"
#             "Dreamin' 'bout the day when you wake up and find\r\n"
#             "That what you're looking for has been here the whole time\r\n"
#             '\r\n'
#             "If you could see that I'm the one who understands you\r\n"
#             "Been here all along, so why can't you see\r\n"
#             'You belong with me\r\n'
#             'You belong with me\r\n'
#             '\r\n'
#             "Walkin' the streets with you and your worn-out jeans\r\n"
#             "I can't help thinkin' this is how it ought to be\r\n"
#             "Laughin' on a park bench, thinkin' to myself\r\n"
#             '"Hey, isn\'t this easy?"\r\n'
#             "And you've got a smile that could light up this whole town\r\n"
#             "I haven't seen it in a while since she brought you down\r\n"
#             "You say you're fine, I know you better than that\r\n"
#             "Hey, what you doin' with a girl like that?\r\n"
#             '\r\n'
#             'She wears high heels, I wear sneakers\r\n'
#             "She's cheer captain and I'm on the bleachers\r\n"
#             "Dreamin' 'bout the day when you wake up and find\r\n"
#             "That what you're looking for has been here the whole time\r\n"
#             '\r\n'
#             "If you could see that I'm the one who understands you\r\n"
#             "Been here all along, so why can't you see\r\n"
#             'You belong with me\r\n'
#             "Standin' by and waitin' at your back door\r\n"
#             'All this time, how could you not know, baby\r\n'
#             'You belong with me\r\n'
#             'You belong with me\r\n'
#             '\r\n'
#             "Oh, I remember you drivin' to my house\r\n"
#             'In the middle of the night\r\n'
#             "I'm the one who makes you laugh\r\n"
#             "When you know you're 'bout to cry\r\n"
#             'And I know your favorite songs\r\n'
#             "And you tell me 'bout your dreams\r\n"
#             'Think I know where you belong\r\n'
#             "Think I know it's with me\r\n"
#             '\r\n'
#             "Can't you see that I'm the one who understands you?\r\n"
#             "Been here all along, so why can't you see\r\n"
#             'You belong with me\r\n'
#             "Standin' by and waitin' at your back door\r\n"
#             'All this time, how could you not know, baby\r\n'
#             'You belong with me\r\n'
#             'You belong with me\r\n'
#             'You belong with me\r\n'
#             'Have you ever thought just maybe\r\n'
#             'You belong with me\r\n'
#             'You belong with me',
#   'mode': 1,
#   'popular_artist': 'Taylor Swift',
#   'popular_artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'popularity': 68,
#   'preview_url': None,
#   'speechiness': 0.0379,
#   'tempo': 129.966,
#   'time_signature': 4,
#   'track_id': '1GEBsLDvJGw7kviySRI6GX',
#   'track_name': 'You Belong With Me',
#   'track_number': 12,
#   'valence': 0.435},
#  {'acousticness': 0.0281,
#   'album_id': '3nzuGtN3nXARvvecier4K0',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273a108e07c661f9fc54de9c43a',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02a108e07c661f9fc54de9c43a',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851a108e07c661f9fc54de9c43a',
#                     'width': 64}],
#   'album_name': 'Different World',
#   'album_release_date': '2018-12-14',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 15,
#   'album_type': 'album',
#   'artist_followers': 38808525,
#   'artist_ids': ['7vk5e3vY1uw9plTHJAMwjN'],
#   'artist_names': ['Alan Walker'],
#   'artist_popularity': 80,
#   'audio_file_path': 'songs/pIWaVJPl0-c.mp4',
#   'combined_genres': ['electro house'],
#   'danceability': 0.468,
#   'disc_number': 1,
#   'duration_ms': 212106,
#   'energy': 0.627,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/698ItKASDavgwZ3WjaWjtz',
#   'instrumentalness': 7.97e-06,
#   'isrc': 'NOG841549010',
#   'key': 6,
#   'liveness': 0.11,
#   'loudness': -5.085,
#   'lyrics': 'You were the shadow to my light, did you feel us?\n'
#             'Another star, you fade away\n'
#             'Afraid our aim is out of sight, wanna see us\n'
#             'Alight\n'
#             '\n'
#             'Where are you now?\n'
#             'Where are you now?\n'
#             'Where are you now?\n'
#             'Was it all in my fantasy?\n'
#             'Where are you now?\n'
#             'Were you only imaginary?\n'
#             '\n'
#             'Where are you now?\n'
#             'Atlantis\n'
#             'Under the sea, under the sea\n'
#             'Where are you now?\n'
#             'Another dream\n'
#             "The monster's running wild inside of me\n"
#             '\n'
#             "I'm faded\n"
#             "I'm faded\n"
#             "So lost, I'm faded\n"
#             "I'm faded\n"
#             "So lost, I'm faded\n"
#             '\n'
#             'These shallow waters never met what I needed\n'
#             "I'm letting go, a deeper dive\n"
#             "Eternal silence of the sea, I'm breathing\n"
#             'Alive\n'
#             '\n'
#             'Where are you now?\n'
#             'Where are you now?\n'
#             'Under the bright but faded lights\n'
#             'You set my heart on fire\n'
#             'Where are you now?\n'
#             'Where are you now?\n'
#             '\n'
#             'Where are you now?\n'
#             'Atlantis\n'
#             'Under the sea, under the sea\n'
#             'Where are you now?\n'
#             'Another dream\n'
#             "The monster's running wild inside of me\n"
#             '\n'
#             "I'm faded\n"
#             "I'm faded\n"
#             "So lost, I'm faded\n"
#             "I'm faded\n"
#             "So lost, I'm faded",
#   'mode': 1,
#   'popular_artist': 'Alan Walker',
#   'popular_artist_id': '7vk5e3vY1uw9plTHJAMwjN',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dd79198f4b4c43aef9c8e8e1c4708a402862dd0e?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.0476,
#   'tempo': 179.642,
#   'time_signature': 4,
#   'track_id': '698ItKASDavgwZ3WjaWjtz',
#   'track_name': 'Faded',
#   'track_number': 15,
#   'valence': 0.159},
#  {'acousticness': 0.229,
#   'album_id': '3nzuGtN3nXARvvecier4K0',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273a108e07c661f9fc54de9c43a',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02a108e07c661f9fc54de9c43a',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851a108e07c661f9fc54de9c43a',
#                     'width': 64}],
#   'album_name': 'Different World',
#   'album_release_date': '2018-12-14',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 15,
#   'album_type': 'album',
#   'artist_followers': 38808525,
#   'artist_ids': ['7vk5e3vY1uw9plTHJAMwjN'],
#   'artist_names': ['Alan Walker'],
#   'artist_popularity': 80,
#   'audio_file_path': 'songs/aZwklvDdaVw.mp4',
#   'combined_genres': ['electro house'],
#   'danceability': 0.673,
#   'disc_number': 1,
#   'duration_ms': 160426,
#   'energy': 0.914,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/3LlmKSHR3Rs0Y3KHQLAYDk',
#   'instrumentalness': 0.000478,
#   'isrc': 'NOG841617010',
#   'key': 10,
#   'liveness': 0.186,
#   'loudness': -3.962,
#   'lyrics': 'Lost in your mind, I wanna know\n'
#             "Am I losin' my mind?\n"
#             'Never let me go\n'
#             '\n'
#             'If this night is not forever, at least we are together\n'
#             "I know I'm not alone\n"
#             "I know I'm not alone\n"
#             '\n'
#             'Anywhere, whenever\n'
#             'Apart but still together\n'
#             "I know I'm not alone\n"
#             "I know I'm not alone\n"
#             '\n'
#             "I know I'm not alone\n"
#             '\n'
#             "I know I'm not alone\n"
#             '\n'
#             "Unconscious mind, l'm wide awake\n"
#             'Wanna feel one last time\n'
#             'Take my pain away\n'
#             '\n'
#             'If this night is not forever, at least we are together\n'
#             "I know I'm not alone\n"
#             "I know I'm not alone\n"
#             '\n'
#             'Anywhere, whenever\n'
#             'Apart but still together\n'
#             "I know I'm not alone\n"
#             "I know I'm not alone\n"
#             '\n'
#             "I know I'm not alone\n"
#             '\n'
#             "I know I'm not alone\n"
#             '\n'
#             "I'm not alone\n"
#             "I'm not alone\n"
#             "I'm not alone (I know I'm not alone)\n"
#             "I'm not alone\n"
#             "I'm not alone\n"
#             "I'm not alone (I know I'm not alone)",
#   'mode': 1,
#   'popular_artist': 'Alan Walker',
#   'popular_artist_id': '7vk5e3vY1uw9plTHJAMwjN',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ab66780b7a2f22456185bfa811515eaef4f7254c?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.0496,
#   'tempo': 97.021,
#   'time_signature': 4,
#   'track_id': '3LlmKSHR3Rs0Y3KHQLAYDk',
#   'track_name': 'Alone',
#   'track_number': 12,
#   'valence': 0.183},
#  {'acousticness': 0.184,
#   'album_id': '2vD3zSQr8hNlg0obNel4TE',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2736eb0b9e73adcf04e4ed3eca4',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e026eb0b9e73adcf04e4ed3eca4',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048516eb0b9e73adcf04e4ed3eca4',
#                     'width': 64}],
#   'album_name': 'Camila',
#   'album_release_date': '2018-01-12',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 11,
#   'album_type': 'album',
#   'artist_followers': 10054418,
#   'artist_ids': ['4nDoRrQiYLoBzwC5BhVJzF', '50co4Is1HCEo8bhOyUWKpn'],
#   'artist_names': ['Camila Cabello', 'Young Thug'],
#   'artist_popularity': 82,
#   'audio_file_path': 'songs/mJLDjIWuPXU.mp4',
#   'combined_genres': ['atl hip hop',
#                       'trap',
#                       'melodic rap',
#                       'rap',
#                       'pop',
#                       'gangster rap',
#                       'atl trap',
#                       'dance pop'],
#   'danceability': 0.765,
#   'disc_number': 1,
#   'duration_ms': 217306,
#   'energy': 0.523,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/1rfofaqEpACxVEHIZBJe6W',
#   'instrumentalness': 3.56e-05,
#   'isrc': 'USSM11706905',
#   'key': 2,
#   'liveness': 0.132,
#   'loudness': -4.333,
#   'lyrics': 'Hey\r\n'
#             '\r\n'
#             'Havana, ooh na-na (ayy)\r\n'
#             'Half of my heart is in Havana, ooh-na-na (ayy, ayy)\r\n'
#             'He took me back to East Atlanta, na-na-na\r\n'
#             'Oh, but my heart is in Havana (ayy)\r\n'
#             "There's somethin' 'bout his manners (uh-huh)\r\n"
#             'Havana, ooh, na-na (uh)\r\n'
#             '\r\n'
#             'He didn\'t walk up with that, "How you doin\'?" (uh)\r\n'
#             '(When he came in the room)\r\n'
#             "He said there's a lot of girls I can do with (uh)\r\n"
#             "(But I can't without you)\r\n"
#             'I knew him forever in a minute (hey)\r\n'
#             '(That summer night in June)\r\n'
#             'And papa says he got malo in him (uh)\r\n'
#             "He got me feelin' like\r\n"
#             '\r\n'
#             'Ooh-ooh-ooh, I knew it when I met him (ayy)\r\n'
#             'I loved him when I left him\r\n'
#             "Got me feelin' like\r\n"
#             'Ooh-ooh-ooh, and then I had to tell him\r\n'
#             'I had to go, oh, na-na-na-na-na (woo)\r\n'
#             '\r\n'
#             'Havana, ooh na-na (ayy, ayy)\r\n'
#             'Half of my heart is in Havana, ooh-na-na (ayy, ayy, uh-huh)\r\n'
#             'He took me back to East Atlanta, na-na-na \r\n'
#             'Oh, but my heart is in Havana (ayy)\r\n'
#             'My heart is in Havana (ayy)\r\n'
#             'Havana, ooh, na-na\r\n'
#             '\r\n'
#             '(Jeffery)\r\n'
#             'Just graduated, fresh on campus, mm\r\n'
#             'Fresh out East Atlanta with no manners, damn\r\n'
#             '(Fresh out East Atlanta)\r\n'
#             'Bump on her bumper like a traffic jam\r\n'
#             'Hey, I was quick to pay that girl like Uncle Sam (here you go, '
#             'ayy)\r\n'
#             "Back it on me (back it up), shawty cravin' on me\r\n"
#             "Get to eatin' on me (on me)\r\n"
#             'She waited on me (then what?)\r\n'
#             "Shawty cakin' on me, got the bacon on me (wait up)\r\n"
#             "This is history in the makin', homie (homie)\r\n"
#             'Point blank, close range, that B \r\n'
#             "If it cost a million, that's me (that's me)\r\n"
#             "I was gettin' mula, baby\r\n"
#             '\r\n'
#             'Havana, ooh na-na (ayy, ayy)\r\n'
#             'Half of my heart is in Havana, ooh-na-na (oh, ayy, ayy, '
#             'uh-huh)\r\n'
#             'He took me back to East Atlanta, na-na-na (oh, no)\r\n'
#             'Oh, but my heart is in Havana (ayy)\r\n'
#             'My heart is in Havana (ayy)\r\n'
#             'Havana, ooh, na-na\r\n'
#             '\r\n'
#             'Ooh na-na, oh na-na-na (ooh-ooh)\r\n'
#             'Take me back, back, back like\r\n'
#             'Ooh na-na, oh na-na-na (yeah, babe)\r\n'
#             'Take me back, back, back like\r\n'
#             'Ooh na-na, oh na-na-na (yeah, yeah)\r\n'
#             'Take me back, back, back like\r\n'
#             'Ooh na-na, oh na-na-na (yeah, babe)\r\n'
#             'Take me back, back, back\r\n'
#             '(Hey, hey)\r\n'
#             'Ooh-ooh-ooh\r\n'
#             'Ooh-ooh-ooh\r\n'
#             'Take me back to my Havana\r\n'
#             '\r\n'
#             'Havana, ooh na-na\r\n'
#             'Half of my heart is in Havana, ooh-na-na (oh, yeah)\r\n'
#             'He took me back to East Atlanta, na-na-na (ayy, ayy)\r\n'
#             'Oh, but my heart is in Havana\r\n'
#             'My heart is in Havana (ayy)\r\n'
#             'Havana, ooh, na-na \r\n'
#             '\r\n'
#             'Uh-huh\r\n'
#             'Oh, na-na-na (oh, na, yeah)\r\n'
#             'Oh, na-na-na\r\n'
#             'Oh, na-na-na\r\n'
#             'No, no, no, take me back\r\n'
#             'Oh, na-na-na\r\n'
#             'Havana, ooh, na-na',
#   'mode': 1,
#   'popular_artist': 'Young Thug',
#   'popular_artist_id': '50co4Is1HCEo8bhOyUWKpn',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/49653dbbec996f228cb6edc046d318cd5a249ee6?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.03,
#   'tempo': 104.988,
#   'time_signature': 4,
#   'track_id': '1rfofaqEpACxVEHIZBJe6W',
#   'track_name': 'Havana (feat. Young Thug)',
#   'track_number': 4,
#   'valence': 0.394},
#  {'acousticness': 0.0254,
#   'album_id': '3ch4qh5d8YjnRT6DezP3xv',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2735073655d273920d6ee62fe89',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e025073655d273920d6ee62fe89',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048515073655d273920d6ee62fe89',
#                     'width': 64}],
#   'album_name': 'Turn It Down',
#   'album_release_date': '2022-03-05',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 1,
#   'album_type': 'single',
#   'artist_followers': 465500,
#   'artist_ids': ['3Tqz477C42DxC4UT7rk3yx'],
#   'artist_names': ['OR3O'],
#   'artist_popularity': 60,
#   'audio_file_path': 'songs/9rj1NPEWOH4.mp4',
#   'combined_genres': ['pov: indie', 'otacore', 'pixel'],
#   'danceability': 0.576,
#   'disc_number': 1,
#   'duration_ms': 229332,
#   'energy': 0.93,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/5SDzo5YMWly9n6hVHvxPwp',
#   'instrumentalness': 4.75e-06,
#   'isrc': 'QZDA82235631',
#   'key': 4,
#   'liveness': 0.491,
#   'loudness': -2.699,
#   'lyrics': 'So, did you hear about the other day?\n'
#             'They say the family is in dismay\n'
#             'I heard that everything was not okay\n'
#             'The house might even fall, and then decay\n'
#             '\n'
#             'What do I do about this future sight?\n'
#             "Don't want to give the people any fright\n"
#             'Need to find Bruno just to make things right\n'
#             'Unless we wanna fall by candle light\n'
#             '\n'
#             'Through doors and through the cracks\n'
#             'I always listen but never act\n'
#             'And though I wish that I could just turn it back\n'
#             'The rumors speeding through a narrow track\n'
#             '\n'
#             'Everything is way too loud\n'
#             'The roar of whispers in every crowd\n'
#             "I'm sick of all the noise right now\n"
#             'Oh, can someone please just turn it down?\n'
#             '\n'
#             "Candle, won't you just keep burning bright?\n"
#             "The prophecy won't be our demise (keep it down)\n"
#             'Clear blue skies, no rain, just shine\n'
#             "If we stick together, we'll be alright (oh-oh-oh)\n"
#             'I can hear your fear\n'
#             'I can make them disappear (turn it down)\n'
#             "There are secrets I won't tell\n"
#             'Not unless they break the spell\n'
#             '\n'
#             "And you could hear it through the casa's halls\n"
#             'A crack and scurry coming from the walls\n'
#             "So, can we answer to the future's call?\n"
#             'Or will we end up losing it all?\n'
#             '\n'
#             "Why couldn't she just shut her mouth tonight?\n"
#             'She ruined everything, just out of spite\n'
#             "Oh no, my power's fading by the day\n"
#             "The pressures sinking in, I can't run away\n"
#             '\n'
#             'Through doors and through the cracks\n'
#             'I always listen but never act\n'
#             'And though I wish that I could just turn it back\n'
#             'The rumors speeding through a narrow track\n'
#             '\n'
#             'Everything is way too loud\n'
#             'The roar of whispers in every crowd\n'
#             "I'm sick of all the noise right now\n"
#             'Oh, can someone please just turn it down?\n'
#             '\n'
#             "Feeling like I'm always just barely there\n"
#             "Only a shadow, and it's never fair\n"
#             "The volume's growing, don't wanna know what's going on at all\n"
#             'Not anymore\n'
#             '\n'
#             "I'm at my final straw\n"
#             "My power's hardly a blessing at all\n"
#             "Heeding to everybody's call\n"
#             'Is there a line that I can draw?\n'
#             '\n'
#             'Everything is way too loud\n'
#             'The roar of whispers in every crowd\n'
#             "I'm sick of all the noise right now\n"
#             'Oh, can someone please just turn it down?\n'
#             '\n'
#             'Turn it down\n'
#             'Oh-oh-oh-oh\n'
#             'Can someone please just turn it down?\n'
#             '\n'
#             'Oh-oh-oh-oh\n'
#             'Turn it down\n'
#             'Can someone please just turn it down?',
#   'mode': 0,
#   'popular_artist': 'OR3O',
#   'popular_artist_id': '3Tqz477C42DxC4UT7rk3yx',
#   'popularity': 44,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4544f17962bfe418eae0489e305a23cdb5824247?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.0919,
#   'tempo': 130.051,
#   'time_signature': 4,
#   'track_id': '5SDzo5YMWly9n6hVHvxPwp',
#   'track_name': 'Turn It Down',
#   'track_number': 1,
#   'valence': 0.804},
#  {'acousticness': 0.155,
#   'album_id': '6t7956yu5zYf5A829XRiHC',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273dbb3dd82da45b7d7f31b1b42',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02dbb3dd82da45b7d7f31b1b42',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851dbb3dd82da45b7d7f31b1b42',
#                     'width': 64}],
#   'album_name': 'The Marshall Mathers LP',
#   'album_release_date': '2000-05-23',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 18,
#   'album_type': 'album',
#   'artist_followers': 85927180,
#   'artist_ids': ['7dGJo4pcD2V6oG8kP0tJRR'],
#   'artist_names': ['Eminem'],
#   'artist_popularity': 91,
#   'audio_file_path': 'songs/D1I1x2pYMK0.mp4',
#   'combined_genres': ['detroit hip hop', 'hip hop', 'rap'],
#   'danceability': 0.897,
#   'disc_number': 1,
#   'duration_ms': 264400,
#   'energy': 0.559,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/5eGEc27nnhtmcOh6RC890a',
#   'instrumentalness': 0.000127,
#   'isrc': 'USIR10000580',
#   'key': 11,
#   'liveness': 0.296,
#   'loudness': -8.268,
#   'lyrics': None,
#   'mode': 1,
#   'popular_artist': 'Eminem',
#   'popular_artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'popularity': 69,
#   'preview_url': None,
#   'speechiness': 0.379,
#   'tempo': 106.991,
#   'time_signature': 4,
#   'track_id': '5eGEc27nnhtmcOh6RC890a',
#   'track_name': 'Kill You',
#   'track_number': 2,
#   'valence': 0.677},
#  {'acousticness': 0.0687,
#   'album_id': '2cWBwpqMsDJC1ZUwz813lo',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2736ca5c90113b30c3c43ffb8f4',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e026ca5c90113b30c3c43ffb8f4',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048516ca5c90113b30c3c43ffb8f4',
#                     'width': 64}],
#   'album_name': 'The Eminem Show',
#   'album_release_date': '2002-05-26',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 20,
#   'album_type': 'album',
#   'artist_followers': 85927180,
#   'artist_ids': ['7dGJo4pcD2V6oG8kP0tJRR'],
#   'artist_names': ['Eminem'],
#   'artist_popularity': 91,
#   'audio_file_path': 'songs/Zxnnuj4Vp_g.mp4',
#   'combined_genres': ['detroit hip hop', 'hip hop', 'rap'],
#   'danceability': 0.908,
#   'disc_number': 1,
#   'duration_ms': 297840,
#   'energy': 0.758,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/7BMO7O7ImjV8HNTH74Tshv',
#   'instrumentalness': 0,
#   'isrc': 'USIR10211054',
#   'key': 9,
#   'liveness': 0.0783,
#   'loudness': -4.753,
#   'lyrics': None,
#   'mode': 0,
#   'popular_artist': 'Eminem',
#   'popular_artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'popularity': 72,
#   'preview_url': None,
#   'speechiness': 0.174,
#   'tempo': 148.015,
#   'time_signature': 4,
#   'track_id': '7BMO7O7ImjV8HNTH74Tshv',
#   'track_name': "Cleanin' Out My Closet",
#   'track_number': 4,
#   'valence': 0.87},
#  {'acousticness': 0.0112,
#   'album_id': '6nYfHQnvkvOTNHnOhDT3sr',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b273c07d5d2fdc02ae252fcd07e5',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e02c07d5d2fdc02ae252fcd07e5',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d00004851c07d5d2fdc02ae252fcd07e5',
#                     'width': 64}],
#   'album_name': 'BE',
#   'album_release_date': '2020-11-20',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 8,
#   'album_type': 'album',
#   'artist_followers': 73852724,
#   'artist_ids': ['3Nrfpe0tUJi4K4DXYWgMUX'],
#   'artist_names': ['BTS'],
#   'artist_popularity': 86,
#   'audio_file_path': 'songs/HaEYUJ2aRHs.mp4',
#   'combined_genres': ['pop', 'k-pop boy group', 'k-pop'],
#   'danceability': 0.746,
#   'disc_number': 1,
#   'duration_ms': 199053,
#   'energy': 0.765,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/5QDLhrAOJJdNAmCTJ8xMyW',
#   'instrumentalness': 0,
#   'isrc': 'QM7282022872',
#   'key': 6,
#   'liveness': 0.0936,
#   'loudness': -4.41,
#   'lyrics': "'Cause I, I, I'm in the stars tonight\n"
#             'So watch me bring the fire, and set the night alight\n'
#             '\n'
#             "Your shoes on, get up in the morn'\n"
#             "Cup of milk, let's rock 'n' roll\n"
#             'King Kong, kick the drum\n'
#             'Rolling on like a Rolling Stone\n'
#             "Sing-song when I'm walking home\n"
#             'Jump up to the top, LeBron\n'
#             'Ding-dong, call me on my phone\n'
#             'Ice tea and a game of ping pong\n'
#             '\n'
#             "This is getting heavy, can you hear the bass boom? I'm ready "
#             '(whoo-hoo)\n'
#             'Life is sweet as honey, yeah, this beat cha-ching like money, '
#             'huh\n'
#             "Disco overload, I'm into that, I'm good to go\n"
#             "I'm diamond, you know I glow up\n"
#             "Hey, so let's go\n"
#             '\n'
#             "'Cause I, I, I'm in the stars tonight\n"
#             'So watch me bring the fire, and set the night alight (hey)\n'
#             'Shining through the city with a little funk and soul\n'
#             "So I'ma light it up like dynamite, whoa-oh-oh\n"
#             '\n'
#             'Bring a friend, join the crowd, whoever wanna come along\n'
#             'Word up, talk the talk, just move like we off the wall\n'
#             "Day or night, the sky's alight, so we dance to the break of dawn "
#             '(hey)\n'
#             'Ladies and gentlemen, I got the medicine\n'
#             'So you should keep ya eyes on the ball, huh\n'
#             '\n'
#             "This is getting heavy, can you hear the bass boom? I'm ready "
#             '(woo-hoo)\n'
#             'Life is sweet as honey, yeah, this beat cha-ching like money, '
#             'huh\n'
#             "Disco overload, I'm into that, I'm good to go\n"
#             "I'm diamond, you know I glow up\n"
#             "Let's go\n"
#             '\n'
#             "'Cause I, I, I'm in the stars tonight\n"
#             'So watch me bring the fire, and set the night alight (hey)\n'
#             'Shining through the city with a little funk and soul\n'
#             "So I'ma light it up like dynamite, whoa-oh-oh\n"
#             '\n'
#             'Dyn-na-na-na, na-na-na-na-na, na-na-na, life is dynamite\n'
#             'Dyn-na-na-na, na-na-na-na-na, na-na-na, life is dynamite\n'
#             'Shining through the city with a little funk and soul\n'
#             "So I'ma light it up like dynamite, whoa-oh-oh\n"
#             '\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Light it up like dynamite\n'
#             '\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Dyn-na-na-na, na-na, na-na, ayy\n'
#             'Light it up like dynamite\n'
#             '\n'
#             "'Cause I, I, I'm in the stars tonight\n"
#             'So watch me bring the fire, and set the night alight\n'
#             'Shining through the city with a little funk and soul\n'
#             "So I'ma light it up like dynamite\n"
#             '\n'
#             "(This is ah) 'cause I, I, I'm in the stars tonight\n"
#             'So watch me bring the fire, and set the night alight (alight, '
#             'oh)\n'
#             'Shining through the city with a little funk and soul\n'
#             "So I'ma light it up like dynamite, whoa-oh-oh (light it up like "
#             'dynamite)\n'
#             '\n'
#             'Dyn-na-na-na, na-na-na-na-na, na-na-na, life is dynamite (life is '
# ...
#             'And life would stay fairly the same\n'
#             "Oh, our friendship wouldn't change at all\n"
#             "But you busted, haven't talked in a year\n"
#             "I mistrusted, now it's all comin' clear\n"
#             'That you only think of yourself\n'
#             "May be loved, but you're lonely as hell, oh\n"
#             '\n'
#             'We used to talk about the fakers in LA\n'
#             "But now you're one of 'em, I guess you got your way\n"
#             "I bet you're tired of all the games you had to play, you had to "
#             'play\n'
#             'You always wanted to take before you give\n'
#             "But what's the fun of it?\n"
#             "I don't know how you live with yourself in your Hollywood house "
#             'in the hills\n'
#             'Gives me chills\n'
#             '\n'
#             'City of angels\n'
#             "That's what they call us, right?\n"
#             'Wish you were able\n'
#             "To see there's so much more to life\n"
#             'Than fortune and fame, validation and pain\n'
#             'When you always want more\n'
#             "There's nothing to gain\n"
#             '\n'
#             'We used to talk about the fakers in LA\n'
#             "But now you're one of 'em, and damn, it hurts to say\n"
#             'Damn, it hurts to say\n'
#             'You always wanted to take before you give\n'
#             "But what's the fun of it?\n"
#             "I don't know how you live with yourself in your Hollywood house "
#             'in the hills\n'
#             'Gives me chills\n'
#             '\n'
#             'City of angels\n'
#             "That's what they call us, right?\n"
#             'Wish you were able\n'
#             "To see there's so much more to life\n"
#             'City of angels\n'
#             "That's what they call us, right?\n"
#             'City of angels',
#   'mode': 1,
#   'popular_artist': 'Em Beihold',
#   'popular_artist_id': '7o2ZQYM7nTsaVdkXY38UAA',
#   'popularity': 13,
#   'preview_url': None,
#   'speechiness': 0.0436,
#   'tempo': 75.018,
#   'time_signature': 4,
#   'track_id': '5amAJIEdIVtWYEi4wGp7Fn',
#   'track_name': 'City of Angels',
#   'track_number': 1,
#   'valence': 0.338},
#  {'acousticness': 0.18,
#   'album_id': '0g81USzuFuid3QkYfxeMXM',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b2735ee0a1dafbbf6d8d430821a3',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e025ee0a1dafbbf6d8d430821a3',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d000048515ee0a1dafbbf6d8d430821a3',
#                     'width': 64}],
#   'album_name': 'ASIN9NE',
#   'album_release_date': '2021-10-08',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 17,
#   'album_type': 'album',
#   'artist_followers': 2755802,
#   'artist_ids': ['6UBA15slIuadJ8h2lPRPos',
#                  '1A8NEJYo3VW9aIZ6l55Dgu',
#                  '7vTyZmNA6LC0WRDg7V6yle',
#                  '1T8S48bD91THNKBByWBDyn'],
#   'artist_names': ['Tech N9ne', 'Joey Cool', 'King Iso', 'Dwayne Johnson'],
#   'artist_popularity': 69,
#   'audio_file_path': 'songs/bDlEN5tDMtg.mp4',
#   'combined_genres': ['detroit hip hop', 'kansas city hip hop', 'pop rap'],
#   'danceability': 0.693,
#   'disc_number': 1,
#   'duration_ms': 219802,
#   'energy': 0.935,
#   'explicit': True,
#   'external_url': 'https://open.spotify.com/track/6M47gaKejso9772SKTa3yH',
#   'instrumentalness': 0,
#   'isrc': 'USZHR2100088',
#   'key': 8,
#   'liveness': 0.179,
#   'loudness': -4.323,
#   'lyrics': "Rumble, they gon' take yo' face off\n"
#             '\n'
#             'Spirit of a lion describes my soul\n'
#             'Give it up to Zion, then my fire grows\n'
#             "Wishin' of a riot inside my lobe\n"
#             "And my trippin' is the highest when I fight my foes!\n"
#             '\n'
#             "Bip, I'ma hit 'em with this, you 'bout to get yo' ass kicked\n"
#             "My technique is so sick, I'm 'bout to make the hit quick\n"
#             "Whole 'lotta muscle, you don't wanna be in a tussle (yeah, yeah)\n"
#             "Better than me? That's rubble\n"
#             "You want trouble? What's up though? (Yeah)\n"
#             '\n'
#             'Feelings hot to kill, a top guerilla\n'
#             'Drop and kneel to pops, I grilled the opp\n'
#             'For real, ya clock, it yield and stop\n'
#             "Ya will is shot, the deal was knock ya 'til ya plop\n"
#             "I got the hell comin' yo way (yeah)\n"
#             'You softer than a thing of Yoplait\n'
#             'Never competitive with the better kid, I go cray\n'
#             "Gonna be deaded because I fed it to the Mo', graves (yeah)\n"
#             '\n'
#             'When you wake up in that wet blood\n'
#             "Ain't no way you 'bout to get up\n"
#             "How you know that I taxed yo' ass?\n"
#             "'Cause you got the motherfuckin' check stub (rrr)\n"
#             'Always gonna have to pay costs\n'
#             "When you steppin' in my way, boss\n"
#             'When I build steel and you stay soft\n'
#             "You're gonna punk out when we face off\n"
#             '\n'
#             "Rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon'-\n"
#             '\n'
#             'Rumble there, young man, they rumble\n'
#             'Run up, get a combo quickly\n'
#             'Help you understand, but stay humble (doo-doo)\n'
#             "Don't nobody wanna talk about the way of the world\n"
#             "The weight of the world'll make 'em all crumble\n"
#             'And I might stumble, but I pick myself up\n'
#             'Brush myself off, my thoughts of a god-damn boss! (Woo)\n'
#             '\n'
#             "I am at their neck like I'm Malcolm X\n"
#             "Like I'm Dr. King, like I'm Cornel West\n"
#             "Like I'm Huey P., like I'm Booker T\n"
#             "Like I'm Rosa Parks, I'ma need my rest\n"
#             "Niggas know what I'm 'bout, I'll run up in yo' house\n"
#             'Feet up all on your couch, sock you right in your mouth\n'
#             "I ain't after no clout, it could really go south\n"
#             "I'm prepared to go to battle whenever there is a bout (ah)\n"
#             '\n'
#             'I am Muhammad\n'
#             "Ali I'm payin' the homage, policy is to be honest\n"
#             'I take it beyond it though\n'
#             'I can relate to ebonics, and really I hate to be ominous\n'
#             'All of your hate is too obvious\n'
#             'I am the hustle, the muscle, I play for the audience\n'
#             'I am a gangster with knowledge\n'
#             'If you wanna enter the ring, I would hate to be opposite\n'
#             '\n'
#             'Jab with the right, jab with the left\n'
#             "Jab with the right, now you got 'em all staggerin'\n"
#             "He gon' come back with the right, back with the left\n"
#             "That's when you step to the side, now dagger\n"
#             "You gon' be damned if you do, damned if you don't\n"
#             "Bastard, I'm like Cassius, my swagger\n"
#             "It really don't matter, pardon, I'm hardened\n"
#             "Lawless, the Martian kickin' that jargon (ah)\n"
#             '\n'
#             "Rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon'-\n"
#             '\n'
#             "Barber cape off how I'm givin' the fade\n"
#             'Based off the description, I gave\n'
#             "Cut the game off, I'm a street fighter\n"
#             'Beat the brakes off like the whip on the stage\n'
#             'Hand out ass whippings\n'
#             'My plate haters ate off, yeah, get Hitler a steak\n'
#             "It'll be chaos like an emerald chase\n"
#             'When I face off in a Nicolas Cage\n'
#             '\n'
#             "Y-y-y-yeah, I'm livin' in rage\n"
#             "Punch a pussy nigga like I'm fistin' his babe\n"
#             "I was sittin' in the 'spital, goin' mental, doc had told me\n"
#             "They'll forget me, but they didn't, I remember them days\n"
#             "And I don't wanna be Batman, nigga, I'm Bane\n"
#             'Literally how the venom enters my veins\n'
#             'Since a little one, Killa really been sick in the brain\n'
#             'And the more I think about it, my life was twisted, wait\n'
#             '\n'
#             "Reminiscin' on when mom and dad would wonder\n"
#             "Why they couldn't reach me like they didn't have my number\n"
#             "Fightin' for my sanity, I never had the hunger\n"
#             "Put a nigga underground quick, that's a bunker\n"
#             "Sh-shock 'em like I'm Master's brother\n"
#             'Better pick your battles, busters halfway under\n'
#             'Hit more times than acupuncture\n'
#             "When it comes to rumblin', I'm Afro Thunder\n"
#             '\n'
#             'Really it be funny when I kick it to you dummies\n'
#             "How I'm grippin' on the iron when I'm rhymin' on the mic\n"
#             "Because it really will get bloody like I'm kickin' it with "
#             'buddies\n'
#             'When I beat a nigga up like I was Iron nigga Mike\n'
#             '\n'
#             "I tell 'em they don't wanna tussle when I'm at 'em, they gon' "
#             'drop\n'
#             'Bet you that he stumble when I jab him then I cross\n'
#             'Leave a nigga humble like, "Damn" when Kenny dropped\n'
#             "'Cause really we can rumble like Jackie in the Bronx\n"
#             "We gon'-\n"
#             '\n'
#             "Rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off\n"
#             "They gon' rumble, they gon' take yo' face off (yeah)\n"
#             '\n'
#             "It's about drive, it's about power\n"
#             'We stay hungry, we devour\n'
#             'Put in the work, put in the hours\n'
#             "And take what's ours (ahoo)\n"
#             'Black and Samoan in my veins\n'
#             "My culture bangin' with Strange\n"
#             "I change the game, so what's my motherfuckin' name? (Rock!)\n"
#             '\n'
#             '(What they gonna get though?)\n'
#             'Desecration, defamation\n'
#             'If you wanna bring it to the masses\n'
#             "Face to face now we escalatin' when I have to put boots to asses\n"
#             "Mean on ya like a dream when I'm rumblin'\n"
#             'You\'re gonna scream, "Mama"\n'
#             'So bring drama to the king Brahma (then what?)\n'
#             "Comin' at ya with extreme mana\n"
#             '(Ahoo, ahoo, ahoo)\n'
#             '\n'
#             'Thank you brother, Tech N9ne\n'
#             'Thank you, Teremana\n'
#             "One take, that's a wrap\n"
#             'Face off, um',
#   'mode': 1,
#   'popular_artist': 'Tech N9ne',
#   'popular_artist_id': '6UBA15slIuadJ8h2lPRPos',
#   'popularity': 62,
#   'preview_url': 'https://p.scdn.co/mp3-preview/641987c1abed761fc84d76b19a8275a7ed5b3baa?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.224,
#   'tempo': 80.882,
#   'time_signature': 4,
#   'track_id': '6M47gaKejso9772SKTa3yH',
#   'track_name': 'Face Off',
#   'track_number': 6,
#   'valence': 0.391},
#  {'acousticness': 0.0895,
#   'album_id': '2v9rQe4F8fVSh5v8bAq0jF',
#   'album_images': [{'height': 640,
#                     'url': 'https://i.scdn.co/image/ab67616d0000b27364f8a309aa3c0a66a31fc374',
#                     'width': 640},
#                    {'height': 300,
#                     'url': 'https://i.scdn.co/image/ab67616d00001e0264f8a309aa3c0a66a31fc374',
#                     'width': 300},
#                    {'height': 64,
#                     'url': 'https://i.scdn.co/image/ab67616d0000485164f8a309aa3c0a66a31fc374',
#                     'width': 64}],
#   'album_name': 'Scared to Be Lonely',
#   'album_release_date': '2017-01-27',
#   'album_release_date_precision': 'day',
#   'album_total_tracks': 1,
#   'album_type': 'single',
#   'artist_followers': 43781820,
#   'artist_ids': ['60d24wfXkVzDSfLS6hyCjZ', '6M2wZ9GZgrQXHCFfjv46we'],
#   'artist_names': ['Martin Garrix', 'Dua Lipa'],
#   'artist_popularity': 88,
#   'audio_file_path': 'songs/vFFT1iAUNDE.mp4',
#   'combined_genres': ['pop dance',
#                       'uk pop',
#                       'pop',
#                       'dutch edm',
#                       'dance pop',
#                       'edm',
#                       'progressive house'],
#   'danceability': 0.584,
#   'disc_number': 1,
#   'duration_ms': 220883,
#   'energy': 0.54,
#   'explicit': False,
#   'external_url': 'https://open.spotify.com/track/3ebXMykcMXOcLeJ9xZ17XH',
#   'instrumentalness': 0,
#   'isrc': 'NLM5S1600025',
#   'key': 1,
#   'liveness': 0.261,
#   'loudness': -7.786,
#   'lyrics': 'It was great at the very start\n'
#             'Hands on each other\n'
#             "Couldn't stand to be far apart\n"
#             'Closer the better\n'
#             '\n'
#             "Now we're picking fights and slamming doors\n"
#             "Magnifyin' all our flaws\n"
#             'And I wonder why, wonder what for\n'
#             'Why we keep coming back for more\n'
#             '\n'
#             'Is it just our bodies?\n'
#             'Are we both losing our minds?\n'
#             "Is the only reason you're holding me tonight\n"
#             "'Cause we're scared to be lonely?\n"
#             'Do we need somebody\n'
#             "Just to feel like we're alright\n"
#             "Is the only reason you're holding me tonight\n"
#             "'Cause we're scared to be lonely?\n"
#             '\n'
#             'Too much time, losing track of us\n'
#             'Where was the real\n'
#             'Undefined, spiraling out of touch\n'
#             'Forgot how it feels\n'
#             '\n'
#             'All the messed up fights and slamming doors\n'
#             "Magnifyin' all our flaws\n"
#             'And I wonder why, wonder what for\n'
#             "It's like we keep coming back for more\n"
#             '\n'
#             'Is it just our bodies?\n'
#             'Are we both losing our minds?\n'
#             "Is the only reason you're holding me tonight\n"
#             "'Cause we're scared to be lonely?\n"
#             'Do we need somebody\n'
#             "Just to feel like we're alright\n"
#             "Is the only reason you're holding me tonight\n"
#             "'Cause we're scared to be lonely?\n"
#             '\n'
#             'Scared to be lonely\n'
#             '\n'
#             "Even when we know it's wrong\n"
#             'Been somebody better for us all along\n'
#             'Tell me, how can we keep holding on, holding on tonight?\n'
#             "'Cause we're scared to be lonely\n"
#             '\n'
#             "Even when we know it's wrong\n"
#             'Been somebody better for us all along\n'
#             'Tell me, how can we keep holding on, holding on tonight?\n'
#             "'Cause we're scared to be lonely\n"
#             '\n'
#             'Is it just our bodies?\n'
#             'Are we both losing our minds?\n'
#             "Is the only reason you're holding me tonight\n"
#             "'Cause we're scared to be lonely\n"
#             '\n'
#             'Scared to be lonely\n'
#             'Scared to be lonely\n'
#             'Scared to be lonely',
#   'mode': 0,
#   'popular_artist': 'Dua Lipa',
#   'popular_artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/49e6a27ef1e85764d5758ae6238f003601a53d7d?cid=fd83c27adc7e41f799e11bbaaab23d34',
#   'speechiness': 0.0576,
#   'tempo': 137.972,
#   'time_signature': 4,
#   'track_id': '3ebXMykcMXOcLeJ9xZ17XH',
#   'track_name': 'Scared to Be Lonely',
#   'track_number': 1,
#   'valence': 0.195}]

# %%
pd.DataFrame(track_data)
# Out:
#                     track_name                track_id  track_number  \
# 0                      Cradles  18A7ha5BitZjmdHTCwXFbU             1
# 1                   Easy On Me  0gplL1WMoJ6iYaPgMCL0gX             1
# 2            Happier Than Ever  4RVwu0g32PAqgUiJoXsdF8            15
# 3                Lose Yourself  7MJQ9Nfxzh8LPZ9e9u68Fq             3
# 4               Therefore I Am  20R4HfKloPKgXDqU7UKk3x            14
# 5                  Mockingbird  561jH07mF1jHuk7KlaeF0s            16
# 6           You Belong With Me  1GEBsLDvJGw7kviySRI6GX            12
# 7                        Faded  698ItKASDavgwZ3WjaWjtz            15
# 8                        Alone  3LlmKSHR3Rs0Y3KHQLAYDk            12
# 9    Havana (feat. Young Thug)  1rfofaqEpACxVEHIZBJe6W             4
# 10                Turn It Down  5SDzo5YMWly9n6hVHvxPwp             1
# 11                    Kill You  5eGEc27nnhtmcOh6RC890a             2
# 12      Cleanin' Out My Closet  7BMO7O7ImjV8HNTH74Tshv             4
# 13                    Dynamite  5QDLhrAOJJdNAmCTJ8xMyW             8
# 14                  Bad Habits  36jnG0GLshZiH7oWkOq7gV             2
# 15                  The Nights  0ct6r3EGTcMLPtrXHDvVjc             2
# 16                      Insane  5flerg6aEao2VayZezVlgu             1
# 17  Bam Bam (feat. Ed Sheeran)  2DB4DdfCFMw1iaR6JaR03a             4
# 18   STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX             3
# 19             Numb Little Bug  3o9kpgkIcffx0iSwxhuNI2             1
# 20                   Despacito  6habFhsOp2NvshLv26DqMb             9
# 21                     Rap God  6or1bKJiZ06IlK0vFvY75k             9
# 22             Let Me Love You  0lYBSQXN6rCTvUZvg9S0lU            13
# 23               Groundhog Day  0QLb1y64s617SAnnDoUZLN             1
# 24           Rewrite The Stars  630sXRhIcfwr2e4RdNtjKN             1
# 25    Look What You Made Me Do  1P17dC1amhFzptugyAO7Il             6
# 26                     7 rings  6ocbgoVGwYJhOv1GgI9NsF            10
# 27           Bohemian Rhapsody  3z8h0TU7ReDPLIbEnYhWZb             7
# 28    Something Just Like This  6RUKPb4LETWmmr3iAEQktW             5
# 29                      Legacy  1mavQ4WCzXSeL2Dm5DS4GQ             6
# 30                  Levitating  39LLxExYz6ewLAcYrzQQyP             5
# 31                     Shivers  75MNhvTCCKsST3YqqUiU9r             1
# 32             drivers license  5wANPM4fQCJwkGd4rN57mH             3
# 33                    good 4 u  4ZtFanR9U6ndgddUvNcjcG             6
# 34              City of Angels  5amAJIEdIVtWYEi4wGp7Fn             1
# 35                    Face Off  6M47gaKejso9772SKTa3yH             6
# 36         Scared to Be Lonely  3ebXMykcMXOcLeJ9xZ17XH             1
#
#     disc_number  duration_ms  explicit  popularity  \
# 0             1       209829     False           0
# 1             1       224694     False          76
# 2             1       298899      True          81
# 3             2       320626      True          68
# 4             1       173539     False          70
# 5             1       250760      True          84
# 6             1       232120     False          68
# 7             1       212106     False          78
# 8             1       160426     False          73
# 9             1       217306     False          79
# 10            1       229332     False          44
# 11            1       264400      True          69
# 12            1       297840      True          72
# 13            1       199053     False          78
# 14            1       230746     False           0
# 15            1       176658     False          83
# 16            1       159714     False          75
# 17            1       206070     False          70
# 18            1       141805      True          29
# 19            1       169237     False          68
# 20            1       229360     False          77
# 21            1       363521      True          73
# 22            1       205946     False          82
# 23            1       173619     False          50
# 24            1       217440     False          69
# 25            1       211853     False          79
# 26            1       178626      True          80
# 27            1       354947     False          70
# 28            1       247160     False          86
# 29            1       296269      True          54
# 30            1       203807     False          77
# 31            1       207853     False          17
# 32            1       242013      True          82
# 33            1       178146      True          82
# 34            1       194308     False          13
# 35            1       219802      True          62
# 36            1       220883     False          76
#
#                                           preview_url          isrc  \
# 0                                                None  GB2LD1800949
# 1   https://p.scdn.co/mp3-preview/a0cd8077c79a4aa3...  USSM12105970
# 2                                                None  USUM72105936
# 3                                                None  USIR10211559
# 4                                                None  USUM72021500
# 5                                                None  USIR10400813
# 6                                                None  USCJY0803328
# 7   https://p.scdn.co/mp3-preview/dd79198f4b4c43ae...  NOG841549010
# 8   https://p.scdn.co/mp3-preview/ab66780b7a2f2245...  NOG841617010
# 9   https://p.scdn.co/mp3-preview/49653dbbec996f22...  USSM11706905
# 10  https://p.scdn.co/mp3-preview/4544f17962bfe418...  QZDA82235631
# 11                                               None  USIR10000580
# 12                                               None  USIR10211054
# 13  https://p.scdn.co/mp3-preview/98e266fea9df84fa...  QM7282022872
# 14                                               None  GBAHS2100318
# 15                                               None  CH3131340464
# 16  https://p.scdn.co/mp3-preview/931dcc3f7deaba9d...  QZHNA2153397
# 17  https://p.scdn.co/mp3-preview/1bd8b56f5623c6ee...  USSM12200047
# 18                                               None  USSM12103949
# 19                                               None  USUM72200626
# 20                                               None  USUM71607007
# 21                                               None  USUM71314079
# 22                                               None  QMZSY1600015
# 23                                               None  QZHN72175830
# 24  https://p.scdn.co/mp3-preview/b59e1bd5efc1916c...  USAT21704623
# 25                                               None  USCJY1750000
# 26                                               None  USUM71900110
# 27                                               None  GBUM71029604
# 28  https://p.scdn.co/mp3-preview/4e117abe76700eb1...  USQX91700278
# 29                                               None  USUM71314077
# 30  https://p.scdn.co/mp3-preview/ac28d1b0be285ed3...  GBAHT1901299
# 31                                               None  GBAHS2100671
# 32                                               None  USUG12004749
# 33                                               None  USUG12101245
# 34                                               None  QZK6P2075238
# 35  https://p.scdn.co/mp3-preview/641987c1abed761f...  USZHR2100088
# 36  https://p.scdn.co/mp3-preview/49e6a27ef1e85764...  NLM5S1600025
#
#                                       album_name  ... key liveness  loudness  \
# 0                                        Cradles  ...   1   0.1790    -1.870
# 1                                     Easy On Me  ...   5   0.1330    -7.519
# 2                              Happier Than Ever  ...   0   0.1280    -8.697
# 3                                        SHADYXV  ...   2   0.3650    -4.545
# 4                              Happier Than Ever  ...   2   0.0583    -7.781
# 5                        Encore (Deluxe Version)  ...   0   0.1560    -3.798
# 6   Fearless (Big Machine Radio Release Special)  ...   6   0.1110    -4.432
# 7                                Different World  ...   6   0.1100    -5.085
# 8                                Different World  ...  10   0.1860    -3.962
# 9                                         Camila  ...   2   0.1320    -4.333
# 10                                  Turn It Down  ...   4   0.4910    -2.699
# 11                       The Marshall Mathers LP  ...  11   0.2960    -8.268
# 12                               The Eminem Show  ...   9   0.0783    -4.753
# 13                                            BE  ...   6   0.0936    -4.410
# 14                                       Shivers  ...  11   0.3660    -3.745
# 15                             The Days / Nights  ...   6   0.2490    -5.298
# 16                                        Insane  ...   4   0.8230    -5.826
# 17                                       Familia  ...   8   0.3330    -6.377
# 18                         F*CK LOVE 3: OVER YOU  ...   1   0.1030    -5.484
# 19                               Numb Little Bug  ...   8   0.2500    -6.892
# 20                                          VIDA  ...   2   0.0670    -4.787
# 21             The Marshall Mathers LP2 (Deluxe)  ...   7   0.7990    -2.660
# 22                                        Encore  ...   8   0.1350    -5.371
# 23                                 Groundhog Day  ...   6   0.0747    -8.124
# 24                             Rewrite The Stars  ...  10   0.1220    -7.005
# 25                                    reputation  ...   9   0.1260    -6.471
# 26                                 thank u, next  ...   1   0.0881   -10.732
# 27   Bohemian Rhapsody (The Original Soundtrack)  ...   0   0.2070    -9.966
# 28                        Memories...Do Not Open  ...  11   0.1640    -6.769
# 29             The Marshall Mathers LP2 (Deluxe)  ...   9   0.1970    -3.711
# 30                              Future Nostalgia  ...   6   0.2130    -2.278
# 31                                       Shivers  ...   2   0.0424    -2.724
# 32                                          SOUR  ...  10   0.1060    -8.810
# 33                                          SOUR  ...   9   0.0849    -5.044
# 34                                City of Angels  ...   4   0.3160    -7.248
# 35                                       ASIN9NE  ...   8   0.1790    -4.323
# 36                           Scared to Be Lonely  ...   1   0.2610    -7.786
#
#    mode speechiness    tempo time_signature valence  \
# 0     1      0.3690   67.443              3   0.630
# 1     1      0.0282  141.981              4   0.130
# 2     1      0.0348   81.055              3   0.297
# 3     1      0.2670  171.403              4   0.059
# 4     1      0.0924   94.016              4   0.663
# 5     1      0.2660   84.039              4   0.254
# 6     1      0.0379  129.966              4   0.435
# 7     1      0.0476  179.642              4   0.159
# 8     1      0.0496   97.021              4   0.183
# 9     1      0.0300  104.988              4   0.394
# 10    0      0.0919  130.051              4   0.804
# 11    1      0.3790  106.991              4   0.677
# 12    0      0.1740  148.015              4   0.870
# 13    0      0.0993  114.044              4   0.737
# 14    0      0.0347  126.011              4   0.537
# 15    1      0.0433  125.983              4   0.654
# 16    0      0.1440  104.899              4   0.797
# 17    1      0.0401   94.996              4   0.956
# 18    1      0.0483  169.928              4   0.478
# 19    0      0.0769   84.974              4   0.638
# 20    1      0.1530  177.928              4   0.839
# 21    1      0.3140  148.134              4   0.625
# 22    1      0.0580  199.892              4   0.159
# 23    1      0.0689   84.967              4   0.510
# 24    1      0.0386  125.046              4   0.284
# 25    0      0.1230  128.070              4   0.506
# 26    0      0.3080  139.848              4   0.330
# 27    0      0.0501  144.320              4   0.247
# 28    0      0.0317  103.019              4   0.446
# 29    0      0.4740  164.125              4   0.534
# 30    0      0.0753  103.014              4   0.914
# 31    1      0.0856  141.020              4   0.822
# 32    1      0.0578  143.875              4   0.137
# 33    1      0.1540  166.928              4   0.688
# 34    1      0.0436   75.018              4   0.338
# 35    1      0.2240   80.882              4   0.391
# 36    0      0.0576  137.972              4   0.195
#
#                                                lyrics        audio_file_path
# 0   I live inside my own world of make-believe\nKi...  songs/Xv9InPzAYbA.mp4
# 1   There ain't no gold in this river\nThat I've b...  songs/H9NJenpBV2I.mp4
# 2   When I'm away from you, I'm happier than ever\...  songs/NSTUVHsb9xw.mp4
# 3                                                None  songs/zlJ0Aj9y67c.mp4
# 4   I'm not your friend or anything, damn\nYou thi...  songs/oDn4eKyhSH4.mp4
# 5                                                None  songs/9kznlAwE-8o.mp4
# 6   You're on the phone with your girlfriend, she'...  songs/wKoHR305w_c.mp4
# 7   You were the shadow to my light, did you feel ...  songs/pIWaVJPl0-c.mp4
# 8   Lost in your mind, I wanna know\nAm I losin' m...  songs/aZwklvDdaVw.mp4
# 9   Hey\r\n\r\nHavana, ooh na-na (ayy)\r\nHalf of ...  songs/mJLDjIWuPXU.mp4
# 10  So, did you hear about the other day?\nThey sa...  songs/9rj1NPEWOH4.mp4
# 11                                               None  songs/D1I1x2pYMK0.mp4
# 12                                               None  songs/Zxnnuj4Vp_g.mp4
# 13  'Cause I, I, I'm in the stars tonight\nSo watc...  songs/HaEYUJ2aRHs.mp4
# 14  (One, two, three, four)\r\n\r\nOoh\r\nEvery ti...  songs/hJWSZDJb-W4.mp4
# 15  (Hey) Once upon a younger year\r\nWhen all our...  songs/W4C-NEWrnSQ.mp4
# 16  Dearly beloved, for your entertainment\r\nIt's...  songs/gFOJkIk8fcs.mp4
# 17  You said you hated the ocean, but you're surfi...  songs/z54b7qAB7p0.mp4
# 18  I do the same thing I told you that I never wo...  songs/XfEMj-z3TtA.mp4
# 19  I don't feel a single thing\r\nHave the pills ...  songs/Mi5rkJUoqn0.mp4
# 20  ¡Ay!\r\nFonsi, DY\r\nOh, oh no, oh no (oh)\r\n...  songs/FXovf5dsRTw.mp4
# 21  Look, I was gonna go easy on you and not to hu...  songs/MBJFPq2Llps.mp4
# 22  I used to believe\r\nWe were burnin' on the ed...  songs/rJ0D1GbDq1Q.mp4
# 23  All my friends are movin' on\nGettin' hitched ...  songs/E-nY_n5fPSg.mp4
# 24  You know I want you\r\nIt's not a secret I try...  songs/RbimXGH5zkE.mp4
# 25  I don't like your little games\nDon't like you...  songs/117xdufmtMY.mp4
# 26  Yeah, breakfast at Tiffany's and bottles of bu...  songs/XZ868t23Pb4.mp4
# 27  Is this the real life? Is this just fantasy?\n...  songs/utwMHfDZ6SA.mp4
# 28  I've been reading books of old\nThe legends an...  songs/owTWCbq_nSk.mp4
# 29  Tell me where to go, tell me what to do\nI'll ...  songs/64jjsEtvkdM.mp4
# 30  If you wanna run away with me, I know a galaxy...  songs/OsfAnsMY21M.mp4
# 31  I took an arrow to the heart\nI never kissed a...  songs/G1ej5up7JG0.mp4
# 32  I got my driver's license last week\nJust like...  songs/tNJhkrpLGT8.mp4
# 33  Well good for you, I guess you moved on really...  songs/aeDdS9aIpck.mp4
# 34  It's hard havin' a heart in the city\nLook at ...  songs/Tq3QbTDRTMs.mp4
# 35  Rumble, they gon' take yo' face off\n\nSpirit ...  songs/bDlEN5tDMtg.mp4
# 36  It was great at the very start\nHands on each ...  songs/vFFT1iAUNDE.mp4
#
# [37 rows x 38 columns]
