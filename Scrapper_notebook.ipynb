# %% [markdown]
# # Imports

# %%
from ytmusicapi import YTMusic
from pprint import pprint
import os
from pytube import YouTube
import urllib.request
import requests
import re
import string
from tkinter import Tk, ttk, filedialog, StringVar
from dotenv import load_dotenv
from spotipy import SpotifyOAuth
from spotipy.oauth2 import SpotifyOauthError
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Scrapper Classes

# %%
class YTScraper:
  def __init__(
    self,
    token_file_path = 'oauth.json',
  ):
    self.yt_music = YTMusic(token_file_path)
    
  def get_search_results(self,search_str):
    return self.yt_music.search(search_str,filter = 'songs')
  
  def get_lyrics(self, video_id):
    video=self.yt_music.get_watch_playlist(videoId=video_id)
    lyrics_id = video['lyrics']
    lyrics = None
    if lyrics_id:
      lyrics=self.yt_music.get_lyrics(lyrics_id)
    return lyrics
  
  def download_song_by_video_id(
    self,
    video_id,
    output_path=None,
  ):
    if output_path is not None:
      os.makedirs(output_path,exist_ok=True)
    else:
      output_path = ""
    yt = YouTube(f"https://youtube.com/watch?v={video_id}", use_oauth = True, allow_oauth_cache=True)
    temp_file = os.path.join(output_path,f"{video_id}.mp4")
    yt.streams.filter(only_audio=True).first().download(output_path=output_path, filename=f"{video_id}.mp4")
    if os.path.exists(temp_file):
      print(f"Downloaded successfully: {temp_file}")
    return os.path.join(output_path,f"{video_id}.mp4")
  
  def scrap_by_search(self, search_str, download_output_file_path = None):
    search_result = self.get_search_results(search_str=search_str)
    video_id = None
    for item in search_result:
      if item['resultType'] in ['song'] and item['category'] == 'Songs':
        video_id = item['videoId']
        break 
    if (video_id):
      lyrics = self.get_lyrics(video_id=video_id)
      if not lyrics:
        lyrics = {'lyrics':None,'source':None}
      download_path = self.download_song_by_video_id(video_id=video_id, output_path=download_output_file_path)
    else:
      raise Exception("Null Video Id")
    return {
      "lyrics" : lyrics['lyrics'],
      "audio_file_path" : download_path
    }
  
class SpotifyScraper:
    def __init__(
        self,
        client_id,
        client_secret,
        redirect_uri,
        scope = "user-library-read playlist-read-private playlist-read-collaborative"
    ):
        self.yt_scraper = YTScraper()
        try:
            self.sp_oauth = SpotifyOAuth(
                client_id=client_id,
                client_secret=client_secret,
                redirect_uri=redirect_uri,
                scope="user-library-read playlist-read-private playlist-read-collaborative",
            )
        except SpotifyOauthError as e:
            print(f"Spotify OAuth setup error: {e}")
            exit(1)
            
        self.access_token = self.get_access_token()
            
    def get_access_token(self):
        # Get access token
        self.token_info = self.sp_oauth.get_cached_token()
        if not self.token_info:
            auth_url = self.sp_oauth.get_authorize_url()
            print("Please go to this URL and authorize the app:", auth_url)
            auth_code = input("Enter the authorization code: ")
            self.token_info = self.sp_oauth.get_access_token(auth_code)
        access_token = self.token_info["access_token"]
        return access_token

    def get_auth_header(self):
        return {"Authorization": "Bearer " + self.access_token}
    # Function to fetch user playlists
    
    def get_user_playlists(self):
        print("Retrieving user playlists...")
        headers = self.get_auth_header()
        response = requests.get("https://api.spotify.com/v1/me/playlists", headers=headers)
        response_json = response.json()
        # for item in response_json["items"]:
        #     playlists[item["name"]] = item["id"]
        print("Playlists retrieved successfully.")
        return response_json
    
    @staticmethod
    def sanitize_filename(filename):
        valid_chars = "-_.() %s%s" % (string.ascii_letters, string.digits)
        return ''.join(c for c in filename if c in valid_chars)

    def get_track_info_by_id(self, track_id):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/tracks/{track_id}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_playlist_info_by_id(self, playlist_id):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_track_info_by_id(self, track_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/tracks?ids={track_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_artist_info_by_id(self, artist_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/artists?ids={artist_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def get_several_audio_feature_by_id(self, track_ids_str):
        headers = self.get_auth_header()
        response = requests.get(f"https://api.spotify.com/v1/audio-features?ids={track_ids_str}", headers=headers)
        if not response.ok:
            raise Exception(f"{response.status_code} : {response.text}")
        response_json = response.json()
        return response_json
    
    def destructure_artist_data(self,artists_list):
        artist_infos = []
        artist_genres = []
        artist_popularities = []
        artist_followers = []
        for artist_obj in artists_list:
            artist_infos.append({
                "name": artist_obj["name"],
                "id": artist_obj["id"],
                "genres": artist_obj.get("genres", []),
                "popularity": artist_obj["popularity"],
                "followers": artist_obj["followers"]["total"]
            })
            artist_genres.extend(artist_obj.get("genres", []))
            artist_popularities.append(artist_obj["popularity"])
            artist_followers.append(artist_obj["followers"]["total"])
        return {
            'artist_infos' : artist_infos,
            'artist_genres' : artist_genres,
            'artist_popularities' : artist_popularities,
            'artist_followers' : artist_followers,
        }
    
    def construct_track_info_dict(self,track_json = None, audio_features_json = None, artist_json = None): 
        
        most_popular_artist = max(artist_json['artist_infos'], key=lambda x: x["popularity"])
        
        search_str = f"{track_json['name']} {most_popular_artist['name']}"
        
        lyrics_audio_data = self.yt_scraper.scrap_by_search(search_str=search_str, download_output_file_path = "songs")
        
        track_info = {
        "track_name": track_json["name"],
        "track_id": track_json["id"],
        "track_number": track_json["track_number"],
        "disc_number": track_json["disc_number"],
        "duration_ms": track_json["duration_ms"],
        "explicit": track_json["explicit"],
        "popularity": track_json["popularity"],
        "preview_url": track_json["preview_url"],
        "isrc": track_json["external_ids"].get("isrc"),
        "album_name": track_json["album"]["name"],
        "album_id": track_json["album"]["id"],
        "album_type": track_json["album"]["album_type"],
        "album_total_tracks": track_json["album"]["total_tracks"],
        "album_release_date": track_json["album"]["release_date"],
        "album_release_date_precision": track_json["album"]["release_date_precision"],
        "album_images": track_json["album"]["images"],
        "popular_artist": most_popular_artist["name"],
        "popular_artist_id": most_popular_artist["id"],
        "artist_names": [artist["name"] for artist in track_json["artists"]],
        "artist_ids": [artist["id"] for artist in track_json["artists"]],
        "combined_genres": list(set(artist_json['artist_genres'])),
        "artist_popularity": most_popular_artist["popularity"],
        "artist_followers": most_popular_artist["followers"],
        "external_url": track_json["external_urls"]["spotify"],
        "acousticness": audio_features_json["acousticness"],
        "danceability": audio_features_json["danceability"],
        "energy": audio_features_json["energy"],
        "instrumentalness": audio_features_json["instrumentalness"],
        "key": audio_features_json["key"],
        "liveness": audio_features_json["liveness"],
        "loudness": audio_features_json["loudness"],
        "mode": audio_features_json["mode"],
        "speechiness": audio_features_json["speechiness"],
        "tempo": audio_features_json["tempo"],
        "time_signature": audio_features_json["time_signature"],
        "valence": audio_features_json["valence"],
    }
        track_info.update(lyrics_audio_data)
        return track_info
        
    
    def get_several_track_data(self, track_ids_list : list[str]):
        data = []
        for idx in range(0,len(track_ids_list),50):
            track_id_str = ",".join(track_ids_list[idx:idx+50])
            tracks_json = self.get_several_track_info_by_id(track_id_str)["tracks"]
            audio_features_json = self.get_several_audio_feature_by_id(track_ids_str=track_id_str)["audio_features"]
            
            
            assert len(tracks_json) == len(audio_features_json)
            for track_obj, audio_feat_obj in zip(tracks_json, audio_features_json):
                artist_ids_list = [artist['id'] for artist in track_obj["artists"]]
                artists_id_str = ','.join(artist_ids_list[:50])
                artists_data = self.get_several_artist_info_by_id(artists_id_str)["artists"]
                destructured_artist_data = self.destructure_artist_data(artists_list=artists_data)                
                data.append(self.construct_track_info_dict(track_obj, audio_feat_obj, destructured_artist_data))
        return data

# %% [markdown]
# ## Scrapping Shuru kro

# %%
# Load environment variables
load_dotenv(dotenv_path='.env')
# Setup Spotify API credentials
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
redirect_uri = os.getenv("REDIRECT_URL")

# %% [markdown]
# ### Scrapper Instance

# %% [markdown]
# ### yt music login for lyrics (copy this line to console)

# %%
# !ytmusicapi oauth
# Out:
# ^C

# %% [markdown]
# ### Scrapper Instantiation

# %%
scrapper = SpotifyScraper(
  client_id=client_id,
  client_secret=client_secret,
  redirect_uri=redirect_uri,
)
# Out:
# Please go to this URL and authorize the app: https://accounts.spotify.com/authorize?client_id=fd83c27adc7e41f799e11bbaaab23d34&response_type=code&redirect_uri=http%3A%2F%2Flocalhost.com%3A8888%2Fcallback&scope=user-library-read+playlist-read-private+playlist-read-collaborative
# C:\Users\Ishan.ACERNITRO5\AppData\Local\Temp\ipykernel_17076\3570085095.py:83: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   self.token_info = self.sp_oauth.get_access_token(auth_code)

# %%
# Yahan pr apne track ids ke list daal dena
track_ids_list = []
# Below is a sample trackid list
track_ids_list = ['7MJQ9Nfxzh8LPZ9e9u68Fq',
 '1GEBsLDvJGw7kviySRI6GX',
 '0gplL1WMoJ6iYaPgMCL0gX',
 '698ItKASDavgwZ3WjaWjtz',
 '3LlmKSHR3Rs0Y3KHQLAYDk',
 '20R4HfKloPKgXDqU7UKk3x',
 '4RVwu0g32PAqgUiJoXsdF8',
 '6habFhsOp2NvshLv26DqMb',
 '18A7ha5BitZjmdHTCwXFbU',
 '75MNhvTCCKsST3YqqUiU9r',
 '1rfofaqEpACxVEHIZBJe6W',
 '5eGEc27nnhtmcOh6RC890a',
 '5PjdY0CKGZdEuoNab3yDmX',
 '6ocbgoVGwYJhOv1GgI9NsF',
 '1mavQ4WCzXSeL2Dm5DS4GQ',
 '3ebXMykcMXOcLeJ9xZ17XH',
 '36jnG0GLshZiH7oWkOq7gV',
 '3z8h0TU7ReDPLIbEnYhWZb',
 '5SDzo5YMWly9n6hVHvxPwp',
 '0ct6r3EGTcMLPtrXHDvVjc',
 '7BMO7O7ImjV8HNTH74Tshv',
 '561jH07mF1jHuk7KlaeF0s',
 '6or1bKJiZ06IlK0vFvY75k',
 '6M47gaKejso9772SKTa3yH',
 '630sXRhIcfwr2e4RdNtjKN',
 '5QDLhrAOJJdNAmCTJ8xMyW',
 '0lYBSQXN6rCTvUZvg9S0lU',
 '5wANPM4fQCJwkGd4rN57mH',
 '4ZtFanR9U6ndgddUvNcjcG',
 '6RUKPb4LETWmmr3iAEQktW',
 '1P17dC1amhFzptugyAO7Il',
 '2DB4DdfCFMw1iaR6JaR03a',
 '3o9kpgkIcffx0iSwxhuNI2',
 '0QLb1y64s617SAnnDoUZLN',
 '5amAJIEdIVtWYEi4wGp7Fn',
 '5flerg6aEao2VayZezVlgu',
 '39LLxExYz6ewLAcYrzQQyP']

# %%
# Track_data is a dictionary of arrays
track_data = scrapper.get_several_track_data(track_ids_list)
# Out:
# Downloaded successfully: songs\soNLLPokjC4.mp4
# Downloaded successfully: songs\LYyUr75fs_o.mp4
# Downloaded successfully: songs\H9NJenpBV2I.mp4
# Downloaded successfully: songs\pIWaVJPl0-c.mp4
# Downloaded successfully: songs\aZwklvDdaVw.mp4
# Downloaded successfully: songs\oDn4eKyhSH4.mp4
# Downloaded successfully: songs\NSTUVHsb9xw.mp4
# Downloaded successfully: songs\FXovf5dsRTw.mp4
# Downloaded successfully: songs\8_Cw99SiHvc.mp4
# Downloaded successfully: songs\G1ej5up7JG0.mp4
# Downloaded successfully: songs\mJLDjIWuPXU.mp4
# Downloaded successfully: songs\soNLLPokjC4.mp4
# Downloaded successfully: songs\XfEMj-z3TtA.mp4
# Downloaded successfully: songs\XZ868t23Pb4.mp4
# Downloaded successfully: songs\64jjsEtvkdM.mp4
# Downloaded successfully: songs\vFFT1iAUNDE.mp4
# Downloaded successfully: songs\hJWSZDJb-W4.mp4
# Downloaded successfully: songs\yl3TsqL0ZPw.mp4
# Downloaded successfully: songs\9rj1NPEWOH4.mp4
# Downloaded successfully: songs\W4C-NEWrnSQ.mp4
# Downloaded successfully: songs\Zxnnuj4Vp_g.mp4
# Downloaded successfully: songs\soNLLPokjC4.mp4
# Downloaded successfully: songs\soNLLPokjC4.mp4
# Downloaded successfully: songs\bDlEN5tDMtg.mp4
# Downloaded successfully: songs\RbimXGH5zkE.mp4
# Downloaded successfully: songs\HaEYUJ2aRHs.mp4
# Downloaded successfully: songs\rJ0D1GbDq1Q.mp4
# Downloaded successfully: songs\l0txe6yk8Kc.mp4
# Downloaded successfully: songs\aeDdS9aIpck.mp4
# Downloaded successfully: songs\owTWCbq_nSk.mp4
# Downloaded successfully: songs\117xdufmtMY.mp4
# Downloaded successfully: songs\z54b7qAB7p0.mp4
# Downloaded successfully: songs\Mi5rkJUoqn0.mp4
# Downloaded successfully: songs\E-nY_n5fPSg.mp4
# Downloaded successfully: songs\Tq3QbTDRTMs.mp4
# Downloaded successfully: songs\gFOJkIk8fcs.mp4
# Downloaded successfully: songs\OsfAnsMY21M.mp4

# %%
track_data_df = pd.DataFrame(track_data)

# %%
track_data_df
# Out:
#                     track_name                track_id  track_number  \
# 0                Lose Yourself  7MJQ9Nfxzh8LPZ9e9u68Fq             3
# 1           You Belong With Me  1GEBsLDvJGw7kviySRI6GX            12
# 2                   Easy On Me  0gplL1WMoJ6iYaPgMCL0gX             1
# 3                        Faded  698ItKASDavgwZ3WjaWjtz            15
# 4                        Alone  3LlmKSHR3Rs0Y3KHQLAYDk            12
# 5               Therefore I Am  20R4HfKloPKgXDqU7UKk3x            14
# 6            Happier Than Ever  4RVwu0g32PAqgUiJoXsdF8            15
# 7                    Despacito  6habFhsOp2NvshLv26DqMb             9
# 8                      Cradles  18A7ha5BitZjmdHTCwXFbU             1
# 9                      Shivers  75MNhvTCCKsST3YqqUiU9r             1
# 10   Havana (feat. Young Thug)  1rfofaqEpACxVEHIZBJe6W             4
# 11                    Kill You  5eGEc27nnhtmcOh6RC890a             2
# 12   STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX             3
# 13                     7 rings  6ocbgoVGwYJhOv1GgI9NsF            10
# 14                      Legacy  1mavQ4WCzXSeL2Dm5DS4GQ             6
# 15         Scared to Be Lonely  3ebXMykcMXOcLeJ9xZ17XH             1
# 16                  Bad Habits  36jnG0GLshZiH7oWkOq7gV             2
# 17           Bohemian Rhapsody  3z8h0TU7ReDPLIbEnYhWZb             7
# 18                Turn It Down  5SDzo5YMWly9n6hVHvxPwp             1
# 19                  The Nights  0ct6r3EGTcMLPtrXHDvVjc             2
# 20      Cleanin' Out My Closet  7BMO7O7ImjV8HNTH74Tshv             4
# 21                 Mockingbird  561jH07mF1jHuk7KlaeF0s            16
# 22                     Rap God  6or1bKJiZ06IlK0vFvY75k             9
# 23                    Face Off  6M47gaKejso9772SKTa3yH             6
# 24           Rewrite The Stars  630sXRhIcfwr2e4RdNtjKN             1
# 25                    Dynamite  5QDLhrAOJJdNAmCTJ8xMyW             8
# 26             Let Me Love You  0lYBSQXN6rCTvUZvg9S0lU            13
# 27             drivers license  5wANPM4fQCJwkGd4rN57mH             3
# 28                    good 4 u  4ZtFanR9U6ndgddUvNcjcG             6
# 29    Something Just Like This  6RUKPb4LETWmmr3iAEQktW             5
# 30    Look What You Made Me Do  1P17dC1amhFzptugyAO7Il             6
# 31  Bam Bam (feat. Ed Sheeran)  2DB4DdfCFMw1iaR6JaR03a             4
# 32             Numb Little Bug  3o9kpgkIcffx0iSwxhuNI2             1
# 33               Groundhog Day  0QLb1y64s617SAnnDoUZLN             1
# 34              City of Angels  5amAJIEdIVtWYEi4wGp7Fn             1
# 35                      Insane  5flerg6aEao2VayZezVlgu             1
# 36                  Levitating  39LLxExYz6ewLAcYrzQQyP             5
#
#     disc_number  duration_ms  explicit  popularity  \
# 0             2       320626      True          68
# 1             1       232120     False          68
# 2             1       224694     False          76
# 3             1       212106     False          78
# 4             1       160426     False          72
# 5             1       173539     False          70
# 6             1       298899      True          80
# 7             1       229360     False          77
# 8             1       209829     False           0
# 9             1       207853     False          15
# 10            1       217306     False          79
# 11            1       264400      True          69
# 12            1       141805      True          28
# 13            1       178626      True          80
# 14            1       296269      True          54
# 15            1       220883     False          76
# 16            1       230746     False           0
# 17            1       354947     False          70
# 18            1       229332     False          43
# 19            1       176658     False          82
# 20            1       297840      True          71
# 21            1       250760      True          84
# 22            1       363521      True          73
# 23            1       219802      True          62
# 24            1       217440     False          69
# 25            1       199053     False          77
# 26            1       205946     False          82
# 27            1       242013      True          82
# 28            1       178146      True          81
# 29            1       247160     False          85
# 30            1       211853     False          79
# 31            1       206070     False          69
# 32            1       169237     False          68
# 33            1       173619     False          50
# 34            1       194308     False          13
# 35            1       159714     False          75
# 36            1       203807     False          76
#
#                                           preview_url          isrc  \
# 0                                                None  USIR10211559
# 1                                                None  USCJY0803328
# 2   https://p.scdn.co/mp3-preview/a0cd8077c79a4aa3...  USSM12105970
# 3   https://p.scdn.co/mp3-preview/dd79198f4b4c43ae...  NOG841549010
# 4   https://p.scdn.co/mp3-preview/ab66780b7a2f2245...  NOG841617010
# 5                                                None  USUM72021500
# 6                                                None  USUM72105936
# 7                                                None  USUM71607007
# 8   https://p.scdn.co/mp3-preview/584c63beb79d87d1...  GB2LD1800949
# 9   https://p.scdn.co/mp3-preview/08cec59d36ac30ae...  GBAHS2100671
# 10  https://p.scdn.co/mp3-preview/49653dbbec996f22...  USSM11706905
# 11                                               None  USIR10000580
# 12  https://p.scdn.co/mp3-preview/718a2eb032524494...  USSM12103949
# 13                                               None  USUM71900110
# 14                                               None  USUM71314077
# 15  https://p.scdn.co/mp3-preview/49e6a27ef1e85764...  NLM5S1600025
# 16  https://p.scdn.co/mp3-preview/22f3a86c8a83e364...  GBAHS2100318
# 17                                               None  GBUM71029604
# 18  https://p.scdn.co/mp3-preview/4544f17962bfe418...  QZDA82235631
# 19                                               None  CH3131340464
# 20                                               None  USIR10211054
# 21                                               None  USIR10400813
# 22                                               None  USUM71314079
# 23  https://p.scdn.co/mp3-preview/641987c1abed761f...  USZHR2100088
# 24  https://p.scdn.co/mp3-preview/b59e1bd5efc1916c...  USAT21704623
# 25  https://p.scdn.co/mp3-preview/98e266fea9df84fa...  QM7282022872
# 26                                               None  QMZSY1600015
# 27                                               None  USUG12004749
# 28                                               None  USUG12101245
# 29  https://p.scdn.co/mp3-preview/4e117abe76700eb1...  USQX91700278
# 30                                               None  USCJY1750000
# 31  https://p.scdn.co/mp3-preview/1bd8b56f5623c6ee...  USSM12200047
# 32                                               None  USUM72200626
# 33                                               None  QZHN72175830
# 34  https://p.scdn.co/mp3-preview/27fd66a1e602fcbf...  QZK6P2075238
# 35  https://p.scdn.co/mp3-preview/931dcc3f7deaba9d...  QZHNA2153397
# 36  https://p.scdn.co/mp3-preview/ac28d1b0be285ed3...  GBAHT1901299
#
#                                       album_name  ... key liveness  loudness  \
# 0                                        SHADYXV  ...   2   0.3650    -4.545
# 1   Fearless (Big Machine Radio Release Special)  ...   6   0.1110    -4.432
# 2                                     Easy On Me  ...   5   0.1330    -7.519
# 3                                Different World  ...   6   0.1100    -5.085
# 4                                Different World  ...  10   0.1860    -3.962
# 5                              Happier Than Ever  ...   2   0.0583    -7.781
# 6                              Happier Than Ever  ...   0   0.1280    -8.697
# 7                                           VIDA  ...   2   0.0670    -4.787
# 8                                        Cradles  ...   1   0.1790    -1.870
# 9                                        Shivers  ...   2   0.0424    -2.724
# 10                                        Camila  ...   2   0.1320    -4.333
# 11                       The Marshall Mathers LP  ...  11   0.2960    -8.268
# 12                         F*CK LOVE 3: OVER YOU  ...   1   0.1030    -5.484
# 13                                 thank u, next  ...   1   0.0881   -10.732
# 14             The Marshall Mathers LP2 (Deluxe)  ...   9   0.1970    -3.711
# 15                           Scared to Be Lonely  ...   1   0.2610    -7.786
# 16                                       Shivers  ...  11   0.3660    -3.745
# 17   Bohemian Rhapsody (The Original Soundtrack)  ...   0   0.2070    -9.966
# 18                                  Turn It Down  ...   4   0.4910    -2.699
# 19                             The Days / Nights  ...   6   0.2490    -5.298
# 20                               The Eminem Show  ...   9   0.0783    -4.753
# 21                       Encore (Deluxe Version)  ...   0   0.1560    -3.798
# 22             The Marshall Mathers LP2 (Deluxe)  ...   7   0.7990    -2.660
# 23                                       ASIN9NE  ...   8   0.1790    -4.323
# 24                             Rewrite The Stars  ...  10   0.1220    -7.005
# 25                                            BE  ...   6   0.0936    -4.410
# 26                                        Encore  ...   8   0.1350    -5.371
# 27                                          SOUR  ...  10   0.1060    -8.810
# 28                                          SOUR  ...   9   0.0849    -5.044
# 29                        Memories...Do Not Open  ...  11   0.1640    -6.769
# 30                                    reputation  ...   9   0.1260    -6.471
# 31                                       Familia  ...   8   0.3330    -6.377
# 32                               Numb Little Bug  ...   8   0.2500    -6.892
# 33                                 Groundhog Day  ...   6   0.0747    -8.124
# 34                                City of Angels  ...   4   0.3160    -7.248
# 35                                        Insane  ...   4   0.8230    -5.826
# 36                              Future Nostalgia  ...   6   0.2130    -2.278
#
#    mode speechiness    tempo time_signature valence  \
# 0     1      0.2670  171.403              4   0.059
# 1     1      0.0379  129.966              4   0.435
# 2     1      0.0282  141.981              4   0.130
# 3     1      0.0476  179.642              4   0.159
# 4     1      0.0496   97.021              4   0.183
# 5     1      0.0924   94.016              4   0.663
# 6     1      0.0348   81.055              3   0.297
# 7     1      0.1530  177.928              4   0.839
# 8     1      0.3690   67.443              3   0.630
# 9     1      0.0856  141.020              4   0.822
# 10    1      0.0300  104.988              4   0.394
# 11    1      0.3790  106.991              4   0.677
# 12    1      0.0483  169.928              4   0.478
# 13    0      0.3080  139.848              4   0.330
# 14    0      0.4740  164.125              4   0.534
# 15    0      0.0576  137.972              4   0.195
# 16    0      0.0347  126.011              4   0.537
# 17    0      0.0501  144.320              4   0.247
# 18    0      0.0919  130.051              4   0.804
# 19    1      0.0433  125.983              4   0.654
# 20    0      0.1740  148.015              4   0.870
# 21    1      0.2660   84.039              4   0.254
# 22    1      0.3140  148.134              4   0.625
# 23    1      0.2240   80.882              4   0.391
# 24    1      0.0386  125.046              4   0.284
# 25    0      0.0993  114.044              4   0.737
# 26    1      0.0580  199.892              4   0.159
# 27    1      0.0578  143.875              4   0.137
# 28    1      0.1540  166.928              4   0.688
# 29    0      0.0317  103.019              4   0.446
# 30    0      0.1230  128.070              4   0.506
# 31    1      0.0401   94.996              4   0.956
# 32    0      0.0769   84.974              4   0.638
# 33    1      0.0689   84.967              4   0.510
# 34    1      0.0436   75.018              4   0.338
# 35    0      0.1440  104.899              4   0.797
# 36    0      0.0753  103.014              4   0.914
#
#                                                lyrics        audio_file_path
# 0   Hey, Em, it's Paul\r\nUh, I was listening to t...  songs\soNLLPokjC4.mp4
# 1   You're on the phone with your girlfriend, she'...  songs\LYyUr75fs_o.mp4
# 2   There ain't no gold in this river\nThat I've b...  songs\H9NJenpBV2I.mp4
# 3   You were the shadow to my light, did you feel ...  songs\pIWaVJPl0-c.mp4
# 4   Lost in your mind, I wanna know\nAm I losin' m...  songs\aZwklvDdaVw.mp4
# 5   I'm not your friend or anything, damn\nYou thi...  songs\oDn4eKyhSH4.mp4
# 6   When I'm away from you, I'm happier than ever\...  songs\NSTUVHsb9xw.mp4
# 7   ¡Ay!\r\nFonsi, DY\r\nOh, oh no, oh no (oh)\r\n...  songs\FXovf5dsRTw.mp4
# 8   I live inside my own world of make-believe\nKi...  songs\8_Cw99SiHvc.mp4
# 9   I took an arrow to the heart\nI never kissed a...  songs\G1ej5up7JG0.mp4
# 10  Hey\r\n\r\nHavana, ooh na-na (ayy)\r\nHalf of ...  songs\mJLDjIWuPXU.mp4
# 11  Hey, Em, it's Paul\r\nUh, I was listening to t...  songs\soNLLPokjC4.mp4
# 12  I do the same thing I told you that I never wo...  songs\XfEMj-z3TtA.mp4
# 13  Yeah, breakfast at Tiffany's and bottles of bu...  songs\XZ868t23Pb4.mp4
# 14  Tell me where to go, tell me what to do\nI'll ...  songs\64jjsEtvkdM.mp4
# 15  It was great at the very start\nHands on each ...  songs\vFFT1iAUNDE.mp4
# 16  (One, two, three, four)\r\n\r\nOoh\r\nEvery ti...  songs\hJWSZDJb-W4.mp4
# 17  Is this the real life? Is this just fantasy?\n...  songs\yl3TsqL0ZPw.mp4
# 18  So, did you hear about the other day?\nThey sa...  songs\9rj1NPEWOH4.mp4
# 19  (Hey) Once upon a younger year\r\nWhen all our...  songs\W4C-NEWrnSQ.mp4
# 20                                               None  songs\Zxnnuj4Vp_g.mp4
# 21  Hey, Em, it's Paul\r\nUh, I was listening to t...  songs\soNLLPokjC4.mp4
# 22  Hey, Em, it's Paul\r\nUh, I was listening to t...  songs\soNLLPokjC4.mp4
# 23  Rumble, they gon' take yo' face off\n\nSpirit ...  songs\bDlEN5tDMtg.mp4
# 24  You know I want you\r\nIt's not a secret I try...  songs\RbimXGH5zkE.mp4
# 25  'Cause I, I, I'm in the stars tonight\nSo watc...  songs\HaEYUJ2aRHs.mp4
# 26  I used to believe\r\nWe were burnin' on the ed...  songs\rJ0D1GbDq1Q.mp4
# 27  I got my driver's license last week\r\nJust li...  songs\l0txe6yk8Kc.mp4
# 28  Well good for you, I guess you moved on really...  songs\aeDdS9aIpck.mp4
# 29  I've been reading books of old\nThe legends an...  songs\owTWCbq_nSk.mp4
# 30  I don't like your little games\nDon't like you...  songs\117xdufmtMY.mp4
# 31  You said you hated the ocean, but you're surfi...  songs\z54b7qAB7p0.mp4
# 32  I don't feel a single thing\r\nHave the pills ...  songs\Mi5rkJUoqn0.mp4
# 33  All my friends are movin' on\nGettin' hitched ...  songs\E-nY_n5fPSg.mp4
# 34  It's hard havin' a heart in the city\nLook at ...  songs\Tq3QbTDRTMs.mp4
# 35  Dearly beloved, for your entertainment\r\nIt's...  songs\gFOJkIk8fcs.mp4
# 36  If you wanna run away with me, I know a galaxy...  songs\OsfAnsMY21M.mp4
#
# [37 rows x 38 columns]

# %%
pprint(track_data_df.loc[12]['lyrics'])
# Out:
# ('I do the same thing I told you that I never would\n'
#  'I told you I changed, even when I knew I never could\n'
#  "Know that I can't find nobody else as good as you\n"
#  'I need you to stay, need you to stay, hey\n'
#  '\n'
#  "I get drunk, wake up, I'm wasted still\n"
#  'I realize the time that I wasted here\n'
#  "I feel like you can't feel the way I feel\n"
#  "I'll be fucked up if you can't be right here\n"
#  '\n'
#  'Oh, whoa (oh, whoa, whoa)\n'
#  'Oh, whoa (oh, whoa)\n'
#  'Oh, whoa (oh, whoa)\n'
#  "I'll be fucked up if you can't be right here\n"
#  '\n'
#  'I do the same thing I told you that I never would\n'
#  'I told you I changed, even when I knew I never could\n'
#  "Know that I can't find nobody else as good as you\n"
#  'I need you to stay, need you to stay, hey\n'
#  '\n'
#  'I do the same thing I told you that I never would\n'
#  'I told you I changed, even when I knew I never could\n'
#  "Know that I can't find nobody else as good as you\n"
#  'I need you to stay, need you to stay, yeah\n'
#  '\n'
#  "When I'm away from you, I miss your touch (ooh)\n"
#  "You're the reason I believe in love\n"
#  "It's been difficult for me to trust (ooh)\n"
#  "And I'm afraid that I'ma fuck it up\n"
#  "Ain't no way that I can leave you stranded\n"
#  "'Cause you ain't never left me empty-handed\n"
#  "And you know that I know that I can't live without you\n"
#  'So, baby, stay\n'
#  '\n'
#  'Oh, whoa (oh, whoa, whoa)\n'
#  'Oh, whoa (oh, whoa)\n'
#  'Oh, whoa (oh, whoa)\n'
#  "I'll be fucked up if you can't be right here\n"
#  '\n'
#  'I do the same thing I told you that I never would\n'
#  'I told you I changed, even when I knew I never could\n'
#  "Know that I can't find nobody else as good as you\n"
#  'I need you to stay, need you to stay, yeah\n'
#  '\n'
#  'I do the same thing I told you that I never would\n'
#  'I told you I changed, even when I knew I never could\n'
#  "Know that I can't find nobody else as good as you\n"
#  'I need you to stay, need you to stay, hey\n'
#  '\n'
#  'Whoa\n'
#  'I need you to stay, need you to stay, hey')

# %%
track_data_df.to_pickle('Track_data_complete.pkl')

# %%
track_data_df.to_csv('Track_data_complete_csv.csv')
